# %% [markdown]
# # Notebook Objective
# The aim of this notebook is to validate the XGB model when used to predict from data that was not part of the training dataset (hidden data).

# %%
# Import libraries
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# To work with numpy arrays
import numpy as np
# ML model building, training and testing
import sklearn
# Kfold split and scoring
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
# Build ML pipeline
from sklearn.pipeline import Pipeline
# Liner regression model building
from sklearn.linear_model import LinearRegression
# Polynomial regression
from sklearn.preprocessing import PolynomialFeatures
# sklearn included transformer
from sklearn.preprocessing import QuantileTransformer
# to split data into test and train
from sklearn.model_selection import train_test_split
# Scaling transform for PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# To run PCA feature reduction
from sklearn.decomposition import PCA
# XGBoost model
from xgboost import XGBRegressor,XGBClassifier
# Random forest regressor
from sklearn.ensemble import RandomForestRegressor
# for regression error calculation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.model_selection import learning_curve
# for regression r2 score calculation
from sklearn.metrics import r2_score
# for regression mse score calculation
from sklearn.metrics import mean_squared_error
# For hyperparameter tuning
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
# To transform the target variable into a normal distribution
from sklearn.compose import TransformedTargetRegressor
# visualisation
from matplotlib import pyplot

# %%
#import csv file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Defining a function to train and test models
def train_test_eval_model(df, reg, features, scale = False, test_size= 0.25, n_pca = None, random_state = 42
                     #, early_stop = False
                     ):
  # takes as an input df: dataframe with all independent variables and the output variable. Output variable must be the last column.
  #                   reg: model constructor, example: reg = LinearRegression()
  #                   features: series of features from the dataset to be used for train/test, compute this using X.columns
  #                   scale = Option to scale features prior to training, default = False
  #                   test_size = float, percentage of data to be used for testing. Default = 0.2 (20%)
  #                   n_pca = int, number of principal components to reduce the independent varibles to. Default = None (no pca is done). Recommended to use scale = True if using pca.
  #                   random_state = int, number to set random split. Defeault = 42.
  print(type(reg).__name__)

  X = df.iloc[:,:-1] # Select all independent variables as X
  y = df.iloc[:,-1]  # Select the last variable in the dataframe as the target variable y

  # Splitting the data into test (25%) and train (75%)
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size, random_state= random_state)

  # Normalize independent variables (both train and test) if required
  if scale == True:
    scaler = StandardScaler()
    fit_scaler = scaler.fit(X_train)
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
  else:
    fit_scaler = None

  # Run PCA if required. Recommended to normalize if PCA will be used
  if n_pca is not None:
    pca = PCA(n_components= n_pca)
    X_train = pca.fit_transform(X_train)
    X_test = pca.transform(X_test)

  # Features into a dataframe
  X_train_df= pd.DataFrame(X_train)
  X_test_df= pd.DataFrame(X_test)

  #if early_stop is not False:
  #    reg.fit(X_train_df,y_train, eval_set = [(X_train, y_train), (X_test, y_test)])
  #else:
  #  reg.fit(X_train_df,y_train)

  eval_set = [(X_train_df, y_train), (X_test_df, y_test)]
  #eval_set = [(X_train, y_train), (X_test, y_test)]

  estimator = reg.fit(X_train_df,y_train, eval_metric=[
      #"error", # use for classification
      #'log_loss' # use for classification
      "rmse",
      'mae'
      ], eval_set = eval_set)

  y_pred_reg = reg.predict(X_test_df)

  results = {}
  r2 = r2_score(y_test, y_pred_reg)
  n = len(y_test)
  k = len(features)
  adj_r2_score = 1-(((1-r2)*(n-1))/(n-k-1))
  mae = mean_absolute_error(y_test,y_pred_reg)
  mse = mean_squared_error(y_test,y_pred_reg)

  print("Features used for model training = ", features)
  print("Number of principal components used for model training = ", n_pca)
  print("MAE = ", mae)
  print("MSE = ", mse)
  print("R2 Score = ", r2 )
  print("Adjusted R2 Score = ", adj_r2_score)

  results['estimator'] = estimator
  #results['scaler'] = fit_scaler
  results['X_train'] = X_train
  results['y_train'] = y_train
  results['X_test'] = X_test
  results['y_test'] = y_test
  results['y_pred_reg'] = y_pred_reg
  results['MAE'] = mae
  results['MSE'] = mse
  results['R2 Score'] = r2
  results['Adjusted R2 Score'] = adj_r2_score
  results['name'] = type(reg).__name__
  results['scaler'] = fit_scaler

  return results

# %% [markdown]
# ## Importing the data of the full Three Rivers 2022 study area

# %%
train_df_val = pd.read_csv('/content/drive/threerivers_2022.csv')

# %%
#train_df_val.head()

# %%
train_df_val.head()
# Out:
#    aspect  slope      NDMI       MSI     SR_B5      SAVI       EVI      NDVI  \
# 0   148.0   34.0 -0.163047  1.389619  0.236590  0.177631  0.163218  0.278390
# 1   128.0   32.0 -0.154491  1.365439  0.230045  0.215350  0.204381  0.354969
# 2   116.0   30.0 -0.148676  1.349282  0.235490  0.210712  0.197411  0.340363
# 3   105.0   32.0 -0.150462  1.354221  0.235545  0.205507  0.191370  0.330471
# 4   105.0   32.0 -0.124275  1.283822  0.235737  0.225911  0.214676  0.369313
#
#        ST_B10     MNDWI     SR_B7     SR_B6     MSAVI       smi
# 0  315.953187 -0.551470  0.249240  0.328770  0.156521  0.083039
# 1  316.144596 -0.589347  0.227158  0.314112  0.189767  0.075184
# 2  315.823302 -0.576456  0.225425  0.317742  0.186172  0.079032
# 3  315.324271 -0.580547  0.223197  0.318980  0.181468  0.090574
# 4  314.794478 -0.581383  0.206477  0.302645  0.200023  0.105643

# %%
# Droppping some unneeded columns
train_df_val = train_df_val[['aspect','slope','NDMI', 'MSI'
                                ,'SR_B5','SAVI','EVI','NDVI','ST_B10'
                                ,'MNDWI','SR_B7','SR_B6','MSAVI','smi']]

# %%
# Splitting independant and target variables
X = train_df_val.drop('smi',1)
y = train_df_val['smi']
# Out:
# <ipython-input-26-2f2194aca3f3>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = train_df_val.drop('smi',1)

# %%
X.head()
# Out:
#    aspect  slope      NDMI       MSI     SR_B5      SAVI       EVI      NDVI  \
# 0   148.0   34.0 -0.163047  1.389619  0.236590  0.177631  0.163218  0.278390
# 1   128.0   32.0 -0.154491  1.365439  0.230045  0.215350  0.204381  0.354969
# 2   116.0   30.0 -0.148676  1.349282  0.235490  0.210712  0.197411  0.340363
# 3   105.0   32.0 -0.150462  1.354221  0.235545  0.205507  0.191370  0.330471
# 4   105.0   32.0 -0.124275  1.283822  0.235737  0.225911  0.214676  0.369313
#
#        ST_B10     MNDWI     SR_B7     SR_B6     MSAVI
# 0  315.953187 -0.551470  0.249240  0.328770  0.156521
# 1  316.144596 -0.589347  0.227158  0.314112  0.189767
# 2  315.823302 -0.576456  0.225425  0.317742  0.186172
# 3  315.324271 -0.580547  0.223197  0.318980  0.181468
# 4  314.794478 -0.581383  0.206477  0.302645  0.200023

# %% [markdown]
# ## Model training, testing and validation

# %% [markdown]
# #### 1- Using Kfold split:
# The model is trained on 9/10 parts of the data (K = 10) and tested on the 10th part of the data. Prediction accuracy is measured by r2 for each fold.

# %%
# Creating a cross validation object
cv = KFold(n_splits=10, random_state=0, shuffle=True)

# %%
# Creating an XGBoost model (best parameters so far)
#build multiple linear regression model
xgb_reg = XGBRegressor(
      max_depth= 10
    , learning_rate= 0.1 # learning speed
    , n_estimators = 100 # the number of runs XGBoost will try to learn
    , colsample_bylevel = 0.8 # sample of columns to be used to avoid overfitting
    #, gamma=0.1
    #, early_stopping_rounds = 10
    )

# %%
# Estimating r2 score for each k-fold CV to evaluate the model accuracy
scores = cross_val_score(xgb_reg, X, y, scoring='r2',
                         cv=cv, n_jobs=-1, verbose = 5)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   37.2s finished

# %%
scores
# Out:
# array([0.98203061, 0.98355169, 0.9831965 , 0.98242982, 0.98231374,
#        0.98262088, 0.98298449, 0.98397617, 0.98347316, 0.9837771 ])

# %%
scores.mean()
# Out:
# 0.9830354161015757

# %% [markdown]
# #### 2- Using part of the data (25%) as a hidden/holdout dataset:
# The Three Rivers 2022 data is split into 75% training/testing and 25% percent is for hidden validation.
# The 75% of the data which is used for training/testing is split as 75% training and 25% testing.
# *   Full data length = 100%
# *   Training data length = 100% * 75% * 75%
# *   Testing data length = 100% * 75% * 25%
# *   Validation (hidden) data length = 100% * 25%

# %%
# Getting the top 80% rows to be used as training/validation data
ThreeRivers_2022_train_df = train_df_val.iloc[:int(len(train_df_val)*0.75), :]

# %%
# Getting the bottom 20% rows to be used as the hidden testing data
ThreeRivers_2022_test_df = train_df_val.iloc[int(len(train_df_val)*0.75):, :]

# %%
# Confirming that the data was split correctly 80% : 20%
len(ThreeRivers_2022_train_df) + len(ThreeRivers_2022_test_df) - len(train_df_val)
# Out:
# 0

# %%
len(ThreeRivers_2022_test_df) / len(ThreeRivers_2022_train_df)
# Out:
# 0.3333333333333333

# %%
# Getting the column names of the training data (required by the training function)
features = list(ThreeRivers_2022_train_df.columns)[:-1]

# %%
results_train_noPCA = train_test_eval_model(ThreeRivers_2022_train_df, xgb_reg, features = features, scale = False, test_size= 0.25, n_pca = None)
# Out:
# XGBRegressor
# [0]	validation_0-rmse:0.16559	validation_0-mae:0.13153	validation_1-rmse:0.16685	validation_1-mae:0.13220
# [1]	validation_0-rmse:0.14966	validation_0-mae:0.11884	validation_1-rmse:0.15089	validation_1-mae:0.11955
# [2]	validation_0-rmse:0.13530	validation_0-mae:0.10741	validation_1-rmse:0.13651	validation_1-mae:0.10815
# [3]	validation_0-rmse:0.12240	validation_0-mae:0.09714	validation_1-rmse:0.12362	validation_1-mae:0.09792
# [4]	validation_0-rmse:0.11083	validation_0-mae:0.08794	validation_1-rmse:0.11206	validation_1-mae:0.08877
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.10043	validation_0-mae:0.07966	validation_1-rmse:0.10171	validation_1-mae:0.08056
# [6]	validation_0-rmse:0.09108	validation_0-mae:0.07223	validation_1-rmse:0.09243	validation_1-mae:0.07320
# [7]	validation_0-rmse:0.08271	validation_0-mae:0.06556	validation_1-rmse:0.08416	validation_1-mae:0.06666
# [8]	validation_0-rmse:0.07520	validation_0-mae:0.05959	validation_1-rmse:0.07681	validation_1-mae:0.06084
# [9]	validation_0-rmse:0.06846	validation_0-mae:0.05423	validation_1-rmse:0.07020	validation_1-mae:0.05562
# [10]	validation_0-rmse:0.06245	validation_0-mae:0.04944	validation_1-rmse:0.06435	validation_1-mae:0.05099
# [11]	validation_0-rmse:0.05706	validation_0-mae:0.04515	validation_1-rmse:0.05916	validation_1-mae:0.04689
# [12]	validation_0-rmse:0.05223	validation_0-mae:0.04131	validation_1-rmse:0.05455	validation_1-mae:0.04326
# [13]	validation_0-rmse:0.04794	validation_0-mae:0.03791	validation_1-rmse:0.05048	validation_1-mae:0.04005
# [14]	validation_0-rmse:0.04411	validation_0-mae:0.03487	validation_1-rmse:0.04686	validation_1-mae:0.03720
# [15]	validation_0-rmse:0.04074	validation_0-mae:0.03219	validation_1-rmse:0.04379	validation_1-mae:0.03478
# [16]	validation_0-rmse:0.03769	validation_0-mae:0.02978	validation_1-rmse:0.04106	validation_1-mae:0.03261
# [17]	validation_0-rmse:0.03499	validation_0-mae:0.02765	validation_1-rmse:0.03869	validation_1-mae:0.03073
# [18]	validation_0-rmse:0.03260	validation_0-mae:0.02576	validation_1-rmse:0.03661	validation_1-mae:0.02907
# [19]	validation_0-rmse:0.03049	validation_0-mae:0.02409	validation_1-rmse:0.03480	validation_1-mae:0.02761
# [20]	validation_0-rmse:0.02863	validation_0-mae:0.02261	validation_1-rmse:0.03326	validation_1-mae:0.02635
# [21]	validation_0-rmse:0.02698	validation_0-mae:0.02130	validation_1-rmse:0.03195	validation_1-mae:0.02526
# [22]	validation_0-rmse:0.02553	validation_0-mae:0.02015	validation_1-rmse:0.03082	validation_1-mae:0.02430
# [23]	validation_0-rmse:0.02426	validation_0-mae:0.01912	validation_1-rmse:0.02986	validation_1-mae:0.02349
# [24]	validation_0-rmse:0.02311	validation_0-mae:0.01820	validation_1-rmse:0.02903	validation_1-mae:0.02278
# [25]	validation_0-rmse:0.02213	validation_0-mae:0.01740	validation_1-rmse:0.02835	validation_1-mae:0.02219
# [26]	validation_0-rmse:0.02125	validation_0-mae:0.01669	validation_1-rmse:0.02778	validation_1-mae:0.02169
# [27]	validation_0-rmse:0.02049	validation_0-mae:0.01607	validation_1-rmse:0.02730	validation_1-mae:0.02126
# [28]	validation_0-rmse:0.01982	validation_0-mae:0.01553	validation_1-rmse:0.02689	validation_1-mae:0.02088
# [29]	validation_0-rmse:0.01925	validation_0-mae:0.01506	validation_1-rmse:0.02655	validation_1-mae:0.02057
# [30]	validation_0-rmse:0.01873	validation_0-mae:0.01464	validation_1-rmse:0.02626	validation_1-mae:0.02030
# [31]	validation_0-rmse:0.01827	validation_0-mae:0.01426	validation_1-rmse:0.02602	validation_1-mae:0.02007
# [32]	validation_0-rmse:0.01785	validation_0-mae:0.01391	validation_1-rmse:0.02579	validation_1-mae:0.01986
# [33]	validation_0-rmse:0.01750	validation_0-mae:0.01362	validation_1-rmse:0.02562	validation_1-mae:0.01969
# [34]	validation_0-rmse:0.01717	validation_0-mae:0.01333	validation_1-rmse:0.02547	validation_1-mae:0.01954
# [35]	validation_0-rmse:0.01686	validation_0-mae:0.01308	validation_1-rmse:0.02535	validation_1-mae:0.01942
# [36]	validation_0-rmse:0.01661	validation_0-mae:0.01286	validation_1-rmse:0.02524	validation_1-mae:0.01931
# [37]	validation_0-rmse:0.01636	validation_0-mae:0.01264	validation_1-rmse:0.02515	validation_1-mae:0.01921
# [38]	validation_0-rmse:0.01614	validation_0-mae:0.01246	validation_1-rmse:0.02507	validation_1-mae:0.01913
# [39]	validation_0-rmse:0.01590	validation_0-mae:0.01226	validation_1-rmse:0.02500	validation_1-mae:0.01905
# [40]	validation_0-rmse:0.01571	validation_0-mae:0.01210	validation_1-rmse:0.02494	validation_1-mae:0.01899
# [41]	validation_0-rmse:0.01553	validation_0-mae:0.01195	validation_1-rmse:0.02491	validation_1-mae:0.01895
# [42]	validation_0-rmse:0.01535	validation_0-mae:0.01180	validation_1-rmse:0.02485	validation_1-mae:0.01889
# [43]	validation_0-rmse:0.01521	validation_0-mae:0.01168	validation_1-rmse:0.02482	validation_1-mae:0.01886
# [44]	validation_0-rmse:0.01505	validation_0-mae:0.01154	validation_1-rmse:0.02478	validation_1-mae:0.01882
# [45]	validation_0-rmse:0.01492	validation_0-mae:0.01144	validation_1-rmse:0.02476	validation_1-mae:0.01879
# [46]	validation_0-rmse:0.01481	validation_0-mae:0.01134	validation_1-rmse:0.02474	validation_1-mae:0.01877
# [47]	validation_0-rmse:0.01468	validation_0-mae:0.01123	validation_1-rmse:0.02471	validation_1-mae:0.01874
# [48]	validation_0-rmse:0.01458	validation_0-mae:0.01114	validation_1-rmse:0.02469	validation_1-mae:0.01872
# [49]	validation_0-rmse:0.01445	validation_0-mae:0.01104	validation_1-rmse:0.02466	validation_1-mae:0.01870
# [50]	validation_0-rmse:0.01433	validation_0-mae:0.01094	validation_1-rmse:0.02465	validation_1-mae:0.01868
# [51]	validation_0-rmse:0.01420	validation_0-mae:0.01083	validation_1-rmse:0.02463	validation_1-mae:0.01866
# [52]	validation_0-rmse:0.01413	validation_0-mae:0.01077	validation_1-rmse:0.02461	validation_1-mae:0.01865
# [53]	validation_0-rmse:0.01404	validation_0-mae:0.01069	validation_1-rmse:0.02460	validation_1-mae:0.01864
# [54]	validation_0-rmse:0.01392	validation_0-mae:0.01060	validation_1-rmse:0.02459	validation_1-mae:0.01863
# [55]	validation_0-rmse:0.01384	validation_0-mae:0.01053	validation_1-rmse:0.02458	validation_1-mae:0.01862
# [56]	validation_0-rmse:0.01378	validation_0-mae:0.01048	validation_1-rmse:0.02458	validation_1-mae:0.01861
# [57]	validation_0-rmse:0.01369	validation_0-mae:0.01040	validation_1-rmse:0.02457	validation_1-mae:0.01860
# [58]	validation_0-rmse:0.01363	validation_0-mae:0.01035	validation_1-rmse:0.02456	validation_1-mae:0.01859
# [59]	validation_0-rmse:0.01355	validation_0-mae:0.01028	validation_1-rmse:0.02455	validation_1-mae:0.01858
# [60]	validation_0-rmse:0.01346	validation_0-mae:0.01021	validation_1-rmse:0.02454	validation_1-mae:0.01857
# [61]	validation_0-rmse:0.01336	validation_0-mae:0.01013	validation_1-rmse:0.02454	validation_1-mae:0.01857
# [62]	validation_0-rmse:0.01329	validation_0-mae:0.01008	validation_1-rmse:0.02453	validation_1-mae:0.01856
# [63]	validation_0-rmse:0.01321	validation_0-mae:0.01002	validation_1-rmse:0.02452	validation_1-mae:0.01855
# [64]	validation_0-rmse:0.01311	validation_0-mae:0.00994	validation_1-rmse:0.02451	validation_1-mae:0.01854
# [65]	validation_0-rmse:0.01305	validation_0-mae:0.00989	validation_1-rmse:0.02450	validation_1-mae:0.01854
# [66]	validation_0-rmse:0.01300	validation_0-mae:0.00984	validation_1-rmse:0.02450	validation_1-mae:0.01854
# [67]	validation_0-rmse:0.01291	validation_0-mae:0.00977	validation_1-rmse:0.02448	validation_1-mae:0.01852
# [68]	validation_0-rmse:0.01282	validation_0-mae:0.00970	validation_1-rmse:0.02447	validation_1-mae:0.01852
# [69]	validation_0-rmse:0.01276	validation_0-mae:0.00966	validation_1-rmse:0.02446	validation_1-mae:0.01851
# [70]	validation_0-rmse:0.01268	validation_0-mae:0.00960	validation_1-rmse:0.02445	validation_1-mae:0.01851
# [71]	validation_0-rmse:0.01263	validation_0-mae:0.00956	validation_1-rmse:0.02445	validation_1-mae:0.01850
# [72]	validation_0-rmse:0.01258	validation_0-mae:0.00951	validation_1-rmse:0.02444	validation_1-mae:0.01850
# [73]	validation_0-rmse:0.01252	validation_0-mae:0.00947	validation_1-rmse:0.02444	validation_1-mae:0.01850
# [74]	validation_0-rmse:0.01248	validation_0-mae:0.00944	validation_1-rmse:0.02444	validation_1-mae:0.01849
# [75]	validation_0-rmse:0.01243	validation_0-mae:0.00940	validation_1-rmse:0.02444	validation_1-mae:0.01849
# [76]	validation_0-rmse:0.01239	validation_0-mae:0.00936	validation_1-rmse:0.02443	validation_1-mae:0.01849
# [77]	validation_0-rmse:0.01231	validation_0-mae:0.00930	validation_1-rmse:0.02443	validation_1-mae:0.01848
# [78]	validation_0-rmse:0.01218	validation_0-mae:0.00920	validation_1-rmse:0.02442	validation_1-mae:0.01847
# [79]	validation_0-rmse:0.01210	validation_0-mae:0.00914	validation_1-rmse:0.02442	validation_1-mae:0.01847
# [80]	validation_0-rmse:0.01205	validation_0-mae:0.00911	validation_1-rmse:0.02441	validation_1-mae:0.01847
# [81]	validation_0-rmse:0.01196	validation_0-mae:0.00903	validation_1-rmse:0.02441	validation_1-mae:0.01846
# [82]	validation_0-rmse:0.01189	validation_0-mae:0.00897	validation_1-rmse:0.02441	validation_1-mae:0.01846
# [83]	validation_0-rmse:0.01185	validation_0-mae:0.00894	validation_1-rmse:0.02440	validation_1-mae:0.01846
# [84]	validation_0-rmse:0.01178	validation_0-mae:0.00888	validation_1-rmse:0.02440	validation_1-mae:0.01846
# [85]	validation_0-rmse:0.01172	validation_0-mae:0.00884	validation_1-rmse:0.02440	validation_1-mae:0.01846
# [86]	validation_0-rmse:0.01166	validation_0-mae:0.00879	validation_1-rmse:0.02439	validation_1-mae:0.01845
# [87]	validation_0-rmse:0.01164	validation_0-mae:0.00877	validation_1-rmse:0.02439	validation_1-mae:0.01846
# [88]	validation_0-rmse:0.01161	validation_0-mae:0.00874	validation_1-rmse:0.02439	validation_1-mae:0.01845
# [89]	validation_0-rmse:0.01155	validation_0-mae:0.00869	validation_1-rmse:0.02438	validation_1-mae:0.01845
# [90]	validation_0-rmse:0.01148	validation_0-mae:0.00864	validation_1-rmse:0.02438	validation_1-mae:0.01845
# [91]	validation_0-rmse:0.01146	validation_0-mae:0.00862	validation_1-rmse:0.02438	validation_1-mae:0.01844
# [92]	validation_0-rmse:0.01140	validation_0-mae:0.00857	validation_1-rmse:0.02438	validation_1-mae:0.01844
# [93]	validation_0-rmse:0.01134	validation_0-mae:0.00852	validation_1-rmse:0.02438	validation_1-mae:0.01844
# [94]	validation_0-rmse:0.01131	validation_0-mae:0.00850	validation_1-rmse:0.02438	validation_1-mae:0.01844
# [95]	validation_0-rmse:0.01126	validation_0-mae:0.00846	validation_1-rmse:0.02438	validation_1-mae:0.01844
# [96]	validation_0-rmse:0.01119	validation_0-mae:0.00840	validation_1-rmse:0.02438	validation_1-mae:0.01844
# [97]	validation_0-rmse:0.01115	validation_0-mae:0.00837	validation_1-rmse:0.02437	validation_1-mae:0.01844
# [98]	validation_0-rmse:0.01112	validation_0-mae:0.00835	validation_1-rmse:0.02437	validation_1-mae:0.01843
# [99]	validation_0-rmse:0.01107	validation_0-mae:0.00831	validation_1-rmse:0.02437	validation_1-mae:0.01843
# Features used for model training =  ['aspect', 'slope', 'NDMI', 'MSI', 'SR_B5', 'SAVI', 'EVI', 'NDVI', 'ST_B10', 'MNDWI', 'SR_B7', 'SR_B6', 'MSAVI']
# Number of principal components used for model training =  None
# MAE =  0.01843401233540547
# MSE =  0.0005938810913926381
# R2 Score =  0.9825933644407593
# Adjusted R2 Score =  0.9825644423724732

# %%
# Model prediction accuracy on the validation data
results_train_noPCA['R2 Score']
# Out:
# 0.9825933644407593

# %%
# Getting model prediction from hidden (holdout) part of the data
X_hidden = ThreeRivers_2022_test_df.drop('smi',1)
y_hidden = ThreeRivers_2022_test_df['smi']
y_pred_hidden = results_train_noPCA['estimator'].predict(X_hidden)
# Out:
# <ipython-input-39-97a83897cd66>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X_hidden = ThreeRivers_2022_test_df.drop('smi',1)

# %%
# Model prediction accuracy on the hidden test data
hidden_test_r2 = r2_score(y_hidden,y_pred_hidden)
print('r2 score for the hidden test prediction', hidden_test_r2)
# Out:
# r2 score for the hidden test prediction 0.9684379267763817

# %% [markdown]
# #### 3- Training the model on Barstow 2017 data and testing on hidden 2022 data

# %%
updated_barstow_2017 = pd.read_csv('/content/drive/barstow_2017.csv')

# %%
updated_barstow_2022 = pd.read_csv('/content/drive/barstow_lg_2022.csv')

# %%
# Droppping some unneeded columns
updated_barstow_2017 = updated_barstow_2017[['aspect','slope','NDMI'
                                ,'SR_B5','SAVI','EVI','NDVI','ST_B10'
                                ,'MNDWI','SR_B7','SR_B6','MSAVI','smi']]
updated_barstow_2022 = updated_barstow_2022[['aspect','slope','NDMI'
                                ,'SR_B5','SAVI','EVI','NDVI','ST_B10'
                                ,'MNDWI','SR_B7','SR_B6','MSAVI','smi']]
X_2017 = updated_barstow_2017.drop('smi',1)
y_2017 = updated_barstow_2017['smi']
X_2022 = updated_barstow_2022.drop('smi',1)
y_2022 = updated_barstow_2022['smi']
# Out:
# <ipython-input-7-89ad1a776be9>:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X_2017 = updated_barstow_2017.drop('smi',1)
# <ipython-input-7-89ad1a776be9>:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X_2022 = updated_barstow_2022.drop('smi',1)

# %%
features = list(updated_barstow_2017.columns)[:-1]

# %%
training_results_barstow_2017 = train_test_eval_model(updated_barstow_2017, xgb_reg, features = features, scale = False, test_size= 0.25, n_pca = None)
# Out:
# XGBRegressor
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:0.06727	validation_0-mae:0.04985	validation_1-rmse:0.06745	validation_1-mae:0.04992
# [1]	validation_0-rmse:0.06242	validation_0-mae:0.04623	validation_1-rmse:0.06262	validation_1-mae:0.04631
# [2]	validation_0-rmse:0.05818	validation_0-mae:0.04306	validation_1-rmse:0.05842	validation_1-mae:0.04315
# [3]	validation_0-rmse:0.05449	validation_0-mae:0.04031	validation_1-rmse:0.05475	validation_1-mae:0.04040
# [4]	validation_0-rmse:0.05123	validation_0-mae:0.03787	validation_1-rmse:0.05152	validation_1-mae:0.03797
# [5]	validation_0-rmse:0.04839	validation_0-mae:0.03574	validation_1-rmse:0.04871	validation_1-mae:0.03585
# [6]	validation_0-rmse:0.04588	validation_0-mae:0.03388	validation_1-rmse:0.04624	validation_1-mae:0.03401
# [7]	validation_0-rmse:0.04369	validation_0-mae:0.03225	validation_1-rmse:0.04410	validation_1-mae:0.03239
# [8]	validation_0-rmse:0.04177	validation_0-mae:0.03082	validation_1-rmse:0.04223	validation_1-mae:0.03097
# [9]	validation_0-rmse:0.04014	validation_0-mae:0.02958	validation_1-rmse:0.04065	validation_1-mae:0.02975
# [10]	validation_0-rmse:0.03872	validation_0-mae:0.02851	validation_1-rmse:0.03927	validation_1-mae:0.02869
# [11]	validation_0-rmse:0.03748	validation_0-mae:0.02757	validation_1-rmse:0.03808	validation_1-mae:0.02777
# [12]	validation_0-rmse:0.03643	validation_0-mae:0.02679	validation_1-rmse:0.03709	validation_1-mae:0.02700
# [13]	validation_0-rmse:0.03552	validation_0-mae:0.02608	validation_1-rmse:0.03622	validation_1-mae:0.02630
# [14]	validation_0-rmse:0.03472	validation_0-mae:0.02545	validation_1-rmse:0.03546	validation_1-mae:0.02569
# [15]	validation_0-rmse:0.03401	validation_0-mae:0.02489	validation_1-rmse:0.03479	validation_1-mae:0.02515
# [16]	validation_0-rmse:0.03342	validation_0-mae:0.02442	validation_1-rmse:0.03424	validation_1-mae:0.02470
# [17]	validation_0-rmse:0.03289	validation_0-mae:0.02399	validation_1-rmse:0.03376	validation_1-mae:0.02429
# [18]	validation_0-rmse:0.03241	validation_0-mae:0.02362	validation_1-rmse:0.03331	validation_1-mae:0.02393
# [19]	validation_0-rmse:0.03202	validation_0-mae:0.02330	validation_1-rmse:0.03297	validation_1-mae:0.02363
# [20]	validation_0-rmse:0.03166	validation_0-mae:0.02301	validation_1-rmse:0.03264	validation_1-mae:0.02336
# [21]	validation_0-rmse:0.03134	validation_0-mae:0.02277	validation_1-rmse:0.03237	validation_1-mae:0.02313
# [22]	validation_0-rmse:0.03106	validation_0-mae:0.02254	validation_1-rmse:0.03212	validation_1-mae:0.02292
# [23]	validation_0-rmse:0.03080	validation_0-mae:0.02234	validation_1-rmse:0.03190	validation_1-mae:0.02272
# [24]	validation_0-rmse:0.03055	validation_0-mae:0.02213	validation_1-rmse:0.03168	validation_1-mae:0.02254
# [25]	validation_0-rmse:0.03035	validation_0-mae:0.02198	validation_1-rmse:0.03151	validation_1-mae:0.02239
# [26]	validation_0-rmse:0.03015	validation_0-mae:0.02182	validation_1-rmse:0.03134	validation_1-mae:0.02225
# [27]	validation_0-rmse:0.02997	validation_0-mae:0.02169	validation_1-rmse:0.03119	validation_1-mae:0.02213
# [28]	validation_0-rmse:0.02980	validation_0-mae:0.02156	validation_1-rmse:0.03106	validation_1-mae:0.02201
# [29]	validation_0-rmse:0.02966	validation_0-mae:0.02145	validation_1-rmse:0.03094	validation_1-mae:0.02191
# [30]	validation_0-rmse:0.02953	validation_0-mae:0.02134	validation_1-rmse:0.03084	validation_1-mae:0.02182
# [31]	validation_0-rmse:0.02939	validation_0-mae:0.02124	validation_1-rmse:0.03072	validation_1-mae:0.02173
# [32]	validation_0-rmse:0.02925	validation_0-mae:0.02114	validation_1-rmse:0.03061	validation_1-mae:0.02164
# [33]	validation_0-rmse:0.02915	validation_0-mae:0.02107	validation_1-rmse:0.03054	validation_1-mae:0.02157
# [34]	validation_0-rmse:0.02905	validation_0-mae:0.02099	validation_1-rmse:0.03046	validation_1-mae:0.02150
# [35]	validation_0-rmse:0.02894	validation_0-mae:0.02091	validation_1-rmse:0.03038	validation_1-mae:0.02144
# [36]	validation_0-rmse:0.02883	validation_0-mae:0.02083	validation_1-rmse:0.03030	validation_1-mae:0.02137
# [37]	validation_0-rmse:0.02874	validation_0-mae:0.02076	validation_1-rmse:0.03023	validation_1-mae:0.02131
# [38]	validation_0-rmse:0.02865	validation_0-mae:0.02070	validation_1-rmse:0.03018	validation_1-mae:0.02126
# [39]	validation_0-rmse:0.02856	validation_0-mae:0.02063	validation_1-rmse:0.03011	validation_1-mae:0.02120
# [40]	validation_0-rmse:0.02848	validation_0-mae:0.02056	validation_1-rmse:0.03005	validation_1-mae:0.02114
# [41]	validation_0-rmse:0.02843	validation_0-mae:0.02052	validation_1-rmse:0.03001	validation_1-mae:0.02111
# [42]	validation_0-rmse:0.02837	validation_0-mae:0.02048	validation_1-rmse:0.02998	validation_1-mae:0.02108
# [43]	validation_0-rmse:0.02830	validation_0-mae:0.02043	validation_1-rmse:0.02993	validation_1-mae:0.02103
# [44]	validation_0-rmse:0.02825	validation_0-mae:0.02039	validation_1-rmse:0.02990	validation_1-mae:0.02100
# [45]	validation_0-rmse:0.02818	validation_0-mae:0.02034	validation_1-rmse:0.02985	validation_1-mae:0.02096
# [46]	validation_0-rmse:0.02811	validation_0-mae:0.02028	validation_1-rmse:0.02980	validation_1-mae:0.02091
# [47]	validation_0-rmse:0.02807	validation_0-mae:0.02025	validation_1-rmse:0.02977	validation_1-mae:0.02089
# [48]	validation_0-rmse:0.02804	validation_0-mae:0.02022	validation_1-rmse:0.02975	validation_1-mae:0.02087
# [49]	validation_0-rmse:0.02798	validation_0-mae:0.02018	validation_1-rmse:0.02971	validation_1-mae:0.02083
# [50]	validation_0-rmse:0.02792	validation_0-mae:0.02013	validation_1-rmse:0.02967	validation_1-mae:0.02079
# [51]	validation_0-rmse:0.02786	validation_0-mae:0.02009	validation_1-rmse:0.02962	validation_1-mae:0.02075
# [52]	validation_0-rmse:0.02781	validation_0-mae:0.02005	validation_1-rmse:0.02959	validation_1-mae:0.02073
# [53]	validation_0-rmse:0.02776	validation_0-mae:0.02002	validation_1-rmse:0.02956	validation_1-mae:0.02070
# [54]	validation_0-rmse:0.02772	validation_0-mae:0.01999	validation_1-rmse:0.02953	validation_1-mae:0.02067
# [55]	validation_0-rmse:0.02766	validation_0-mae:0.01994	validation_1-rmse:0.02949	validation_1-mae:0.02064
# [56]	validation_0-rmse:0.02762	validation_0-mae:0.01991	validation_1-rmse:0.02946	validation_1-mae:0.02061
# [57]	validation_0-rmse:0.02755	validation_0-mae:0.01986	validation_1-rmse:0.02942	validation_1-mae:0.02057
# [58]	validation_0-rmse:0.02750	validation_0-mae:0.01981	validation_1-rmse:0.02938	validation_1-mae:0.02054
# [59]	validation_0-rmse:0.02745	validation_0-mae:0.01979	validation_1-rmse:0.02935	validation_1-mae:0.02051
# [60]	validation_0-rmse:0.02741	validation_0-mae:0.01976	validation_1-rmse:0.02933	validation_1-mae:0.02049
# [61]	validation_0-rmse:0.02737	validation_0-mae:0.01972	validation_1-rmse:0.02930	validation_1-mae:0.02047
# [62]	validation_0-rmse:0.02732	validation_0-mae:0.01969	validation_1-rmse:0.02927	validation_1-mae:0.02044
# [63]	validation_0-rmse:0.02728	validation_0-mae:0.01966	validation_1-rmse:0.02924	validation_1-mae:0.02042
# [64]	validation_0-rmse:0.02724	validation_0-mae:0.01963	validation_1-rmse:0.02922	validation_1-mae:0.02040
# [65]	validation_0-rmse:0.02720	validation_0-mae:0.01960	validation_1-rmse:0.02919	validation_1-mae:0.02037
# [66]	validation_0-rmse:0.02717	validation_0-mae:0.01957	validation_1-rmse:0.02917	validation_1-mae:0.02035
# [67]	validation_0-rmse:0.02714	validation_0-mae:0.01955	validation_1-rmse:0.02915	validation_1-mae:0.02033
# [68]	validation_0-rmse:0.02711	validation_0-mae:0.01952	validation_1-rmse:0.02913	validation_1-mae:0.02031
# [69]	validation_0-rmse:0.02706	validation_0-mae:0.01948	validation_1-rmse:0.02910	validation_1-mae:0.02029
# [70]	validation_0-rmse:0.02702	validation_0-mae:0.01945	validation_1-rmse:0.02907	validation_1-mae:0.02026
# [71]	validation_0-rmse:0.02697	validation_0-mae:0.01941	validation_1-rmse:0.02904	validation_1-mae:0.02023
# [72]	validation_0-rmse:0.02694	validation_0-mae:0.01939	validation_1-rmse:0.02902	validation_1-mae:0.02021
# [73]	validation_0-rmse:0.02690	validation_0-mae:0.01936	validation_1-rmse:0.02900	validation_1-mae:0.02019
# [74]	validation_0-rmse:0.02687	validation_0-mae:0.01933	validation_1-rmse:0.02898	validation_1-mae:0.02017
# [75]	validation_0-rmse:0.02682	validation_0-mae:0.01931	validation_1-rmse:0.02895	validation_1-mae:0.02015
# [76]	validation_0-rmse:0.02678	validation_0-mae:0.01928	validation_1-rmse:0.02893	validation_1-mae:0.02014
# [77]	validation_0-rmse:0.02674	validation_0-mae:0.01925	validation_1-rmse:0.02891	validation_1-mae:0.02011
# [78]	validation_0-rmse:0.02672	validation_0-mae:0.01923	validation_1-rmse:0.02890	validation_1-mae:0.02010
# [79]	validation_0-rmse:0.02669	validation_0-mae:0.01921	validation_1-rmse:0.02888	validation_1-mae:0.02009
# [80]	validation_0-rmse:0.02667	validation_0-mae:0.01920	validation_1-rmse:0.02887	validation_1-mae:0.02007
# [81]	validation_0-rmse:0.02664	validation_0-mae:0.01917	validation_1-rmse:0.02885	validation_1-mae:0.02006
# [82]	validation_0-rmse:0.02661	validation_0-mae:0.01915	validation_1-rmse:0.02883	validation_1-mae:0.02004
# [83]	validation_0-rmse:0.02658	validation_0-mae:0.01914	validation_1-rmse:0.02882	validation_1-mae:0.02003
# [84]	validation_0-rmse:0.02655	validation_0-mae:0.01911	validation_1-rmse:0.02880	validation_1-mae:0.02002
# [85]	validation_0-rmse:0.02653	validation_0-mae:0.01910	validation_1-rmse:0.02879	validation_1-mae:0.02000
# [86]	validation_0-rmse:0.02650	validation_0-mae:0.01907	validation_1-rmse:0.02877	validation_1-mae:0.01999
# [87]	validation_0-rmse:0.02647	validation_0-mae:0.01905	validation_1-rmse:0.02875	validation_1-mae:0.01997
# [88]	validation_0-rmse:0.02644	validation_0-mae:0.01903	validation_1-rmse:0.02874	validation_1-mae:0.01996
# [89]	validation_0-rmse:0.02641	validation_0-mae:0.01901	validation_1-rmse:0.02872	validation_1-mae:0.01994
# [90]	validation_0-rmse:0.02640	validation_0-mae:0.01899	validation_1-rmse:0.02871	validation_1-mae:0.01993
# [91]	validation_0-rmse:0.02637	validation_0-mae:0.01897	validation_1-rmse:0.02870	validation_1-mae:0.01991
# [92]	validation_0-rmse:0.02635	validation_0-mae:0.01896	validation_1-rmse:0.02868	validation_1-mae:0.01990
# [93]	validation_0-rmse:0.02632	validation_0-mae:0.01893	validation_1-rmse:0.02867	validation_1-mae:0.01989
# [94]	validation_0-rmse:0.02630	validation_0-mae:0.01892	validation_1-rmse:0.02865	validation_1-mae:0.01988
# [95]	validation_0-rmse:0.02627	validation_0-mae:0.01890	validation_1-rmse:0.02864	validation_1-mae:0.01987
# [96]	validation_0-rmse:0.02626	validation_0-mae:0.01888	validation_1-rmse:0.02863	validation_1-mae:0.01985
# [97]	validation_0-rmse:0.02623	validation_0-mae:0.01886	validation_1-rmse:0.02861	validation_1-mae:0.01984
# [98]	validation_0-rmse:0.02621	validation_0-mae:0.01885	validation_1-rmse:0.02861	validation_1-mae:0.01983
# [99]	validation_0-rmse:0.02619	validation_0-mae:0.01884	validation_1-rmse:0.02860	validation_1-mae:0.01982
# Features used for model training =  ['aspect', 'slope', 'NDMI', 'MSI', 'SR_B5', 'SAVI', 'EVI', 'NDVI', 'ST_B10', 'MNDWI', 'SR_B7', 'SR_B6', 'MSAVI']
# Number of principal components used for model training =  None
# MAE =  0.019824650034226846
# MSE =  0.0008177048309844471
# R2 Score =  0.8459780873676558
# Adjusted R2 Score =  0.8459737662501428

# %%
# Model prediction accuracy on the validation data
training_results_barstow_2017['R2 Score']
# Out:
# 0.8459780873676558

# %%
# Getting model prediction from hidden (holdout) part of the data
y_pred_2022 = training_results_barstow_2017['estimator'].predict(X_2022)

# %%
# Model prediction accuracy on the hidden (holdout) part of the data
r2_2022 = r2_score(y_2022, y_pred_2022)
print('r2 score for the hidden test prediction', r2_2022)
# Out:
# r2 score for the hidden test prediction -3.0106336917920276

# %% [markdown]
# https://stackoverflow.com/questions/23036866/scikit-learn-is-returning-coefficient-of-determination-r2-values-less-than-1
# Since we will train the model on a dataset then attmpt to get predictions on another dataset, the training data needs to be scaled as part of the pre-processing prior to the model training. Scaling will cause the data to have a mean of 0 and a standard deviation of 1. The reason why this is required is that the regression model will train by calculating and reducing the errors between the mean of the data points and the best fit trend. The mean of the training data will differ from that of the test data (since it is a different dataset). This will lead to a r2 value which is outside of the [-1:1] range

# %% [markdown]
# #### Reattempt method 3 while using a standard scaler

# %%
training_results_barstow_2017_scale = train_test_eval_model(updated_barstow_2017, xgb_reg, features = features, scale = True, test_size= 0.25, n_pca = None)
# Out:
# XGBRegressor
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:0.06727	validation_0-mae:0.04985	validation_1-rmse:0.06745	validation_1-mae:0.04992
# [1]	validation_0-rmse:0.06242	validation_0-mae:0.04623	validation_1-rmse:0.06262	validation_1-mae:0.04631
# [2]	validation_0-rmse:0.05818	validation_0-mae:0.04306	validation_1-rmse:0.05842	validation_1-mae:0.04315
# [3]	validation_0-rmse:0.05449	validation_0-mae:0.04031	validation_1-rmse:0.05475	validation_1-mae:0.04040
# [4]	validation_0-rmse:0.05123	validation_0-mae:0.03787	validation_1-rmse:0.05152	validation_1-mae:0.03797
# [5]	validation_0-rmse:0.04839	validation_0-mae:0.03574	validation_1-rmse:0.04871	validation_1-mae:0.03585
# [6]	validation_0-rmse:0.04588	validation_0-mae:0.03388	validation_1-rmse:0.04624	validation_1-mae:0.03401
# [7]	validation_0-rmse:0.04369	validation_0-mae:0.03225	validation_1-rmse:0.04410	validation_1-mae:0.03239
# [8]	validation_0-rmse:0.04177	validation_0-mae:0.03081	validation_1-rmse:0.04223	validation_1-mae:0.03097
# [9]	validation_0-rmse:0.04014	validation_0-mae:0.02958	validation_1-rmse:0.04065	validation_1-mae:0.02975
# [10]	validation_0-rmse:0.03872	validation_0-mae:0.02851	validation_1-rmse:0.03927	validation_1-mae:0.02869
# [11]	validation_0-rmse:0.03748	validation_0-mae:0.02757	validation_1-rmse:0.03808	validation_1-mae:0.02777
# [12]	validation_0-rmse:0.03644	validation_0-mae:0.02678	validation_1-rmse:0.03709	validation_1-mae:0.02700
# [13]	validation_0-rmse:0.03553	validation_0-mae:0.02608	validation_1-rmse:0.03623	validation_1-mae:0.02631
# [14]	validation_0-rmse:0.03472	validation_0-mae:0.02545	validation_1-rmse:0.03546	validation_1-mae:0.02570
# [15]	validation_0-rmse:0.03401	validation_0-mae:0.02489	validation_1-rmse:0.03479	validation_1-mae:0.02515
# [16]	validation_0-rmse:0.03342	validation_0-mae:0.02441	validation_1-rmse:0.03424	validation_1-mae:0.02470
# [17]	validation_0-rmse:0.03289	validation_0-mae:0.02399	validation_1-rmse:0.03374	validation_1-mae:0.02429
# [18]	validation_0-rmse:0.03242	validation_0-mae:0.02362	validation_1-rmse:0.03332	validation_1-mae:0.02393
# [19]	validation_0-rmse:0.03204	validation_0-mae:0.02331	validation_1-rmse:0.03298	validation_1-mae:0.02364
# [20]	validation_0-rmse:0.03168	validation_0-mae:0.02301	validation_1-rmse:0.03264	validation_1-mae:0.02336
# [21]	validation_0-rmse:0.03135	validation_0-mae:0.02277	validation_1-rmse:0.03237	validation_1-mae:0.02313
# [22]	validation_0-rmse:0.03106	validation_0-mae:0.02254	validation_1-rmse:0.03212	validation_1-mae:0.02292
# [23]	validation_0-rmse:0.03083	validation_0-mae:0.02235	validation_1-rmse:0.03192	validation_1-mae:0.02274
# [24]	validation_0-rmse:0.03058	validation_0-mae:0.02216	validation_1-rmse:0.03169	validation_1-mae:0.02256
# [25]	validation_0-rmse:0.03038	validation_0-mae:0.02200	validation_1-rmse:0.03152	validation_1-mae:0.02241
# [26]	validation_0-rmse:0.03018	validation_0-mae:0.02184	validation_1-rmse:0.03137	validation_1-mae:0.02227
# [27]	validation_0-rmse:0.03000	validation_0-mae:0.02170	validation_1-rmse:0.03122	validation_1-mae:0.02215
# [28]	validation_0-rmse:0.02983	validation_0-mae:0.02158	validation_1-rmse:0.03109	validation_1-mae:0.02203
# [29]	validation_0-rmse:0.02969	validation_0-mae:0.02146	validation_1-rmse:0.03097	validation_1-mae:0.02193
# [30]	validation_0-rmse:0.02955	validation_0-mae:0.02135	validation_1-rmse:0.03086	validation_1-mae:0.02183
# [31]	validation_0-rmse:0.02940	validation_0-mae:0.02124	validation_1-rmse:0.03075	validation_1-mae:0.02173
# [32]	validation_0-rmse:0.02927	validation_0-mae:0.02114	validation_1-rmse:0.03065	validation_1-mae:0.02164
# [33]	validation_0-rmse:0.02915	validation_0-mae:0.02105	validation_1-rmse:0.03056	validation_1-mae:0.02157
# [34]	validation_0-rmse:0.02905	validation_0-mae:0.02097	validation_1-rmse:0.03048	validation_1-mae:0.02149
# [35]	validation_0-rmse:0.02894	validation_0-mae:0.02089	validation_1-rmse:0.03041	validation_1-mae:0.02143
# [36]	validation_0-rmse:0.02883	validation_0-mae:0.02081	validation_1-rmse:0.03033	validation_1-mae:0.02135
# [37]	validation_0-rmse:0.02873	validation_0-mae:0.02073	validation_1-rmse:0.03025	validation_1-mae:0.02129
# [38]	validation_0-rmse:0.02864	validation_0-mae:0.02067	validation_1-rmse:0.03019	validation_1-mae:0.02124
# [39]	validation_0-rmse:0.02856	validation_0-mae:0.02061	validation_1-rmse:0.03013	validation_1-mae:0.02119
# [40]	validation_0-rmse:0.02847	validation_0-mae:0.02054	validation_1-rmse:0.03007	validation_1-mae:0.02113
# [41]	validation_0-rmse:0.02841	validation_0-mae:0.02050	validation_1-rmse:0.03002	validation_1-mae:0.02109
# [42]	validation_0-rmse:0.02835	validation_0-mae:0.02045	validation_1-rmse:0.02998	validation_1-mae:0.02106
# [43]	validation_0-rmse:0.02828	validation_0-mae:0.02040	validation_1-rmse:0.02993	validation_1-mae:0.02101
# [44]	validation_0-rmse:0.02821	validation_0-mae:0.02034	validation_1-rmse:0.02989	validation_1-mae:0.02097
# [45]	validation_0-rmse:0.02814	validation_0-mae:0.02029	validation_1-rmse:0.02984	validation_1-mae:0.02093
# [46]	validation_0-rmse:0.02808	validation_0-mae:0.02025	validation_1-rmse:0.02979	validation_1-mae:0.02089
# [47]	validation_0-rmse:0.02802	validation_0-mae:0.02021	validation_1-rmse:0.02976	validation_1-mae:0.02086
# [48]	validation_0-rmse:0.02796	validation_0-mae:0.02016	validation_1-rmse:0.02971	validation_1-mae:0.02082
# [49]	validation_0-rmse:0.02791	validation_0-mae:0.02012	validation_1-rmse:0.02968	validation_1-mae:0.02079
# [50]	validation_0-rmse:0.02786	validation_0-mae:0.02008	validation_1-rmse:0.02963	validation_1-mae:0.02075
# [51]	validation_0-rmse:0.02780	validation_0-mae:0.02004	validation_1-rmse:0.02960	validation_1-mae:0.02072
# [52]	validation_0-rmse:0.02774	validation_0-mae:0.02000	validation_1-rmse:0.02956	validation_1-mae:0.02069
# [53]	validation_0-rmse:0.02770	validation_0-mae:0.01996	validation_1-rmse:0.02953	validation_1-mae:0.02066
# [54]	validation_0-rmse:0.02765	validation_0-mae:0.01993	validation_1-rmse:0.02950	validation_1-mae:0.02063
# [55]	validation_0-rmse:0.02760	validation_0-mae:0.01989	validation_1-rmse:0.02946	validation_1-mae:0.02060
# [56]	validation_0-rmse:0.02756	validation_0-mae:0.01985	validation_1-rmse:0.02943	validation_1-mae:0.02057
# [57]	validation_0-rmse:0.02751	validation_0-mae:0.01982	validation_1-rmse:0.02940	validation_1-mae:0.02055
# [58]	validation_0-rmse:0.02747	validation_0-mae:0.01979	validation_1-rmse:0.02937	validation_1-mae:0.02052
# [59]	validation_0-rmse:0.02741	validation_0-mae:0.01975	validation_1-rmse:0.02933	validation_1-mae:0.02049
# [60]	validation_0-rmse:0.02737	validation_0-mae:0.01971	validation_1-rmse:0.02930	validation_1-mae:0.02046
# [61]	validation_0-rmse:0.02732	validation_0-mae:0.01968	validation_1-rmse:0.02927	validation_1-mae:0.02043
# [62]	validation_0-rmse:0.02727	validation_0-mae:0.01964	validation_1-rmse:0.02924	validation_1-mae:0.02041
# [63]	validation_0-rmse:0.02723	validation_0-mae:0.01962	validation_1-rmse:0.02922	validation_1-mae:0.02039
# [64]	validation_0-rmse:0.02721	validation_0-mae:0.01960	validation_1-rmse:0.02920	validation_1-mae:0.02037
# [65]	validation_0-rmse:0.02717	validation_0-mae:0.01957	validation_1-rmse:0.02918	validation_1-mae:0.02035
# [66]	validation_0-rmse:0.02713	validation_0-mae:0.01953	validation_1-rmse:0.02915	validation_1-mae:0.02033
# [67]	validation_0-rmse:0.02709	validation_0-mae:0.01950	validation_1-rmse:0.02913	validation_1-mae:0.02030
# [68]	validation_0-rmse:0.02705	validation_0-mae:0.01948	validation_1-rmse:0.02911	validation_1-mae:0.02028
# [69]	validation_0-rmse:0.02701	validation_0-mae:0.01945	validation_1-rmse:0.02908	validation_1-mae:0.02026
# [70]	validation_0-rmse:0.02698	validation_0-mae:0.01942	validation_1-rmse:0.02906	validation_1-mae:0.02024
# [71]	validation_0-rmse:0.02695	validation_0-mae:0.01940	validation_1-rmse:0.02904	validation_1-mae:0.02022
# [72]	validation_0-rmse:0.02692	validation_0-mae:0.01938	validation_1-rmse:0.02902	validation_1-mae:0.02021
# [73]	validation_0-rmse:0.02689	validation_0-mae:0.01936	validation_1-rmse:0.02900	validation_1-mae:0.02020
# [74]	validation_0-rmse:0.02685	validation_0-mae:0.01933	validation_1-rmse:0.02898	validation_1-mae:0.02017
# [75]	validation_0-rmse:0.02682	validation_0-mae:0.01930	validation_1-rmse:0.02896	validation_1-mae:0.02015
# [76]	validation_0-rmse:0.02680	validation_0-mae:0.01928	validation_1-rmse:0.02894	validation_1-mae:0.02014
# [77]	validation_0-rmse:0.02676	validation_0-mae:0.01926	validation_1-rmse:0.02892	validation_1-mae:0.02012
# [78]	validation_0-rmse:0.02673	validation_0-mae:0.01924	validation_1-rmse:0.02891	validation_1-mae:0.02011
# [79]	validation_0-rmse:0.02670	validation_0-mae:0.01921	validation_1-rmse:0.02889	validation_1-mae:0.02009
# [80]	validation_0-rmse:0.02667	validation_0-mae:0.01919	validation_1-rmse:0.02887	validation_1-mae:0.02008
# [81]	validation_0-rmse:0.02664	validation_0-mae:0.01917	validation_1-rmse:0.02886	validation_1-mae:0.02006
# [82]	validation_0-rmse:0.02662	validation_0-mae:0.01915	validation_1-rmse:0.02884	validation_1-mae:0.02005
# [83]	validation_0-rmse:0.02659	validation_0-mae:0.01913	validation_1-rmse:0.02882	validation_1-mae:0.02003
# [84]	validation_0-rmse:0.02656	validation_0-mae:0.01911	validation_1-rmse:0.02881	validation_1-mae:0.02002
# [85]	validation_0-rmse:0.02653	validation_0-mae:0.01909	validation_1-rmse:0.02879	validation_1-mae:0.02001
# [86]	validation_0-rmse:0.02650	validation_0-mae:0.01907	validation_1-rmse:0.02877	validation_1-mae:0.01999
# [87]	validation_0-rmse:0.02648	validation_0-mae:0.01904	validation_1-rmse:0.02876	validation_1-mae:0.01997
# [88]	validation_0-rmse:0.02646	validation_0-mae:0.01903	validation_1-rmse:0.02875	validation_1-mae:0.01996
# [89]	validation_0-rmse:0.02643	validation_0-mae:0.01901	validation_1-rmse:0.02874	validation_1-mae:0.01995
# [90]	validation_0-rmse:0.02641	validation_0-mae:0.01899	validation_1-rmse:0.02872	validation_1-mae:0.01994
# [91]	validation_0-rmse:0.02638	validation_0-mae:0.01897	validation_1-rmse:0.02870	validation_1-mae:0.01992
# [92]	validation_0-rmse:0.02636	validation_0-mae:0.01895	validation_1-rmse:0.02869	validation_1-mae:0.01991
# [93]	validation_0-rmse:0.02634	validation_0-mae:0.01894	validation_1-rmse:0.02868	validation_1-mae:0.01990
# [94]	validation_0-rmse:0.02631	validation_0-mae:0.01892	validation_1-rmse:0.02867	validation_1-mae:0.01989
# [95]	validation_0-rmse:0.02629	validation_0-mae:0.01890	validation_1-rmse:0.02866	validation_1-mae:0.01988
# [96]	validation_0-rmse:0.02627	validation_0-mae:0.01889	validation_1-rmse:0.02865	validation_1-mae:0.01988
# [97]	validation_0-rmse:0.02626	validation_0-mae:0.01888	validation_1-rmse:0.02864	validation_1-mae:0.01987
# [98]	validation_0-rmse:0.02624	validation_0-mae:0.01887	validation_1-rmse:0.02863	validation_1-mae:0.01986
# [99]	validation_0-rmse:0.02622	validation_0-mae:0.01885	validation_1-rmse:0.02862	validation_1-mae:0.01985
# Features used for model training =  ['aspect', 'slope', 'NDMI', 'MSI', 'SR_B5', 'SAVI', 'EVI', 'NDVI', 'ST_B10', 'MNDWI', 'SR_B7', 'SR_B6', 'MSAVI']
# Number of principal components used for model training =  None
# MAE =  0.019846982954625943
# MSE =  0.0008193075823996035
# R2 Score =  0.8456761950110466
# Adjusted R2 Score =  0.8456718654238794

# %%
training_results_barstow_2017_scale['R2 Score']
# Out:
# 0.8456761950110466

# %%
# Applying standard scalar to the 2022 data X features. The scaler should be fit to the training data (since the testing data is hidden)
scaled_X_2022 = training_results_barstow_2017_scale['scaler'].transform(X_2022.values)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Getting model prediction from hidden (holdout) part of the data
y_pred_2022_scale = training_results_barstow_2017_scale['estimator'].predict(scaled_X_2022)

# %%
# Model prediction accuracy on the hidden 2022 test data
hidden_2022_test_r2_scaled = r2_score(y_2022,y_pred_2022_scale)
hidden_2022_test_r2_scaled
# Out:
# -3.017788476297018

# %%
hidden_2022_test_mae = mean_absolute_error(y_2022,y_pred_2022_scale)
hidden_2022_test_mae
# Out:
# 0.14746839935350964

# %%
hidden_2022_test_mse = mean_squared_error(y_2022,y_pred_2022_scale)
hidden_2022_test_mse
# Out:
# 0.025725778376965693

# %% [markdown]
# #### 4- Train model on ThreeRivers22 data and test on ThreeRivers21 data (with and without scaling)

# %%
train_df = pd.read_csv('/content/drive/threerivers_2022.csv')

# %%
train_df = train_df[['aspect','slope','NDMI'
                                 ,'SR_B5','SAVI','EVI','NDVI','ST_B10'
                                 ,'MNDWI','SR_B7','SR_B6','MSAVI','smi']]

# %%
test_df = pd.read_csv('/content/drive/threerivers_2021.csv')

# %%
test_df = test_df[['aspect','slope','NDMI'
                                 ,'SR_B5','SAVI','EVI','NDVI','ST_B10'
                                 ,'MNDWI','SR_B7','SR_B6','MSAVI','smi']]

# %%
X_2022 = train_df.drop('smi',1)
y_2022 = train_df['smi']
X_2021 = test_df.drop('smi',1)
y_2021 = test_df['smi']
# Out:
# <ipython-input-77-05b9bde90667>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X_2022 = train_df.drop('smi',1)
# <ipython-input-77-05b9bde90667>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X_2021 = test_df.drop('smi',1)

# %%
features = list(train_df.columns)[:-1]

# %%
training_results_threerivers_2022 = train_test_eval_model(train_df, xgb_reg, features = features, scale = False, test_size= 0.25, n_pca = None)
# Out:
# XGBRegressor
# [0]	validation_0-rmse:0.17064	validation_0-mae:0.13990	validation_1-rmse:0.16922	validation_1-mae:0.13824
# [1]	validation_0-rmse:0.15413	validation_0-mae:0.12631	validation_1-rmse:0.15290	validation_1-mae:0.12488
# [2]	validation_0-rmse:0.13931	validation_0-mae:0.11411	validation_1-rmse:0.13828	validation_1-mae:0.11290
# [3]	validation_0-rmse:0.12598	validation_0-mae:0.10312	validation_1-rmse:0.12518	validation_1-mae:0.10217
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:0.11403	validation_0-mae:0.09326	validation_1-rmse:0.11345	validation_1-mae:0.09254
# [5]	validation_0-rmse:0.10330	validation_0-mae:0.08441	validation_1-rmse:0.10295	validation_1-mae:0.08390
# [6]	validation_0-rmse:0.09365	validation_0-mae:0.07645	validation_1-rmse:0.09352	validation_1-mae:0.07617
# [7]	validation_0-rmse:0.08502	validation_0-mae:0.06933	validation_1-rmse:0.08512	validation_1-mae:0.06928
# [8]	validation_0-rmse:0.07726	validation_0-mae:0.06293	validation_1-rmse:0.07758	validation_1-mae:0.06309
# [9]	validation_0-rmse:0.07031	validation_0-mae:0.05720	validation_1-rmse:0.07090	validation_1-mae:0.05761
# [10]	validation_0-rmse:0.06409	validation_0-mae:0.05207	validation_1-rmse:0.06498	validation_1-mae:0.05275
# [11]	validation_0-rmse:0.05856	validation_0-mae:0.04750	validation_1-rmse:0.05971	validation_1-mae:0.04842
# [12]	validation_0-rmse:0.05361	validation_0-mae:0.04343	validation_1-rmse:0.05507	validation_1-mae:0.04460
# [13]	validation_0-rmse:0.04920	validation_0-mae:0.03981	validation_1-rmse:0.05096	validation_1-mae:0.04122
# [14]	validation_0-rmse:0.04525	validation_0-mae:0.03657	validation_1-rmse:0.04737	validation_1-mae:0.03826
# [15]	validation_0-rmse:0.04176	validation_0-mae:0.03370	validation_1-rmse:0.04422	validation_1-mae:0.03565
# [16]	validation_0-rmse:0.03867	validation_0-mae:0.03116	validation_1-rmse:0.04148	validation_1-mae:0.03338
# [17]	validation_0-rmse:0.03594	validation_0-mae:0.02893	validation_1-rmse:0.03907	validation_1-mae:0.03137
# [18]	validation_0-rmse:0.03352	validation_0-mae:0.02695	validation_1-rmse:0.03701	validation_1-mae:0.02964
# [19]	validation_0-rmse:0.03139	validation_0-mae:0.02519	validation_1-rmse:0.03524	validation_1-mae:0.02815
# [20]	validation_0-rmse:0.02952	validation_0-mae:0.02365	validation_1-rmse:0.03374	validation_1-mae:0.02687
# [21]	validation_0-rmse:0.02788	validation_0-mae:0.02230	validation_1-rmse:0.03245	validation_1-mae:0.02577
# [22]	validation_0-rmse:0.02645	validation_0-mae:0.02111	validation_1-rmse:0.03133	validation_1-mae:0.02481
# [23]	validation_0-rmse:0.02519	validation_0-mae:0.02007	validation_1-rmse:0.03040	validation_1-mae:0.02399
# [24]	validation_0-rmse:0.02409	validation_0-mae:0.01916	validation_1-rmse:0.02961	validation_1-mae:0.02330
# [25]	validation_0-rmse:0.02311	validation_0-mae:0.01834	validation_1-rmse:0.02893	validation_1-mae:0.02269
# [26]	validation_0-rmse:0.02228	validation_0-mae:0.01765	validation_1-rmse:0.02839	validation_1-mae:0.02218
# [27]	validation_0-rmse:0.02153	validation_0-mae:0.01701	validation_1-rmse:0.02792	validation_1-mae:0.02175
# [28]	validation_0-rmse:0.02088	validation_0-mae:0.01646	validation_1-rmse:0.02753	validation_1-mae:0.02137
# [29]	validation_0-rmse:0.02030	validation_0-mae:0.01596	validation_1-rmse:0.02721	validation_1-mae:0.02106
# [30]	validation_0-rmse:0.01979	validation_0-mae:0.01553	validation_1-rmse:0.02692	validation_1-mae:0.02077
# [31]	validation_0-rmse:0.01936	validation_0-mae:0.01515	validation_1-rmse:0.02669	validation_1-mae:0.02054
# [32]	validation_0-rmse:0.01897	validation_0-mae:0.01482	validation_1-rmse:0.02649	validation_1-mae:0.02034
# [33]	validation_0-rmse:0.01865	validation_0-mae:0.01454	validation_1-rmse:0.02634	validation_1-mae:0.02019
# [34]	validation_0-rmse:0.01833	validation_0-mae:0.01426	validation_1-rmse:0.02620	validation_1-mae:0.02004
# [35]	validation_0-rmse:0.01805	validation_0-mae:0.01402	validation_1-rmse:0.02609	validation_1-mae:0.01992
# [36]	validation_0-rmse:0.01783	validation_0-mae:0.01382	validation_1-rmse:0.02599	validation_1-mae:0.01982
# [37]	validation_0-rmse:0.01762	validation_0-mae:0.01363	validation_1-rmse:0.02590	validation_1-mae:0.01973
# [38]	validation_0-rmse:0.01741	validation_0-mae:0.01345	validation_1-rmse:0.02583	validation_1-mae:0.01965
# [39]	validation_0-rmse:0.01719	validation_0-mae:0.01327	validation_1-rmse:0.02577	validation_1-mae:0.01958
# [40]	validation_0-rmse:0.01703	validation_0-mae:0.01312	validation_1-rmse:0.02572	validation_1-mae:0.01952
# [41]	validation_0-rmse:0.01687	validation_0-mae:0.01298	validation_1-rmse:0.02568	validation_1-mae:0.01948
# [42]	validation_0-rmse:0.01672	validation_0-mae:0.01285	validation_1-rmse:0.02564	validation_1-mae:0.01944
# [43]	validation_0-rmse:0.01657	validation_0-mae:0.01273	validation_1-rmse:0.02560	validation_1-mae:0.01940
# [44]	validation_0-rmse:0.01643	validation_0-mae:0.01261	validation_1-rmse:0.02557	validation_1-mae:0.01936
# [45]	validation_0-rmse:0.01630	validation_0-mae:0.01249	validation_1-rmse:0.02555	validation_1-mae:0.01933
# [46]	validation_0-rmse:0.01618	validation_0-mae:0.01239	validation_1-rmse:0.02553	validation_1-mae:0.01931
# [47]	validation_0-rmse:0.01606	validation_0-mae:0.01229	validation_1-rmse:0.02551	validation_1-mae:0.01929
# [48]	validation_0-rmse:0.01598	validation_0-mae:0.01222	validation_1-rmse:0.02550	validation_1-mae:0.01927
# [49]	validation_0-rmse:0.01587	validation_0-mae:0.01213	validation_1-rmse:0.02548	validation_1-mae:0.01925
# [50]	validation_0-rmse:0.01577	validation_0-mae:0.01204	validation_1-rmse:0.02547	validation_1-mae:0.01924
# [51]	validation_0-rmse:0.01569	validation_0-mae:0.01197	validation_1-rmse:0.02546	validation_1-mae:0.01922
# [52]	validation_0-rmse:0.01558	validation_0-mae:0.01188	validation_1-rmse:0.02544	validation_1-mae:0.01921
# [53]	validation_0-rmse:0.01548	validation_0-mae:0.01180	validation_1-rmse:0.02544	validation_1-mae:0.01921
# [54]	validation_0-rmse:0.01541	validation_0-mae:0.01174	validation_1-rmse:0.02543	validation_1-mae:0.01920
# [55]	validation_0-rmse:0.01532	validation_0-mae:0.01166	validation_1-rmse:0.02542	validation_1-mae:0.01919
# [56]	validation_0-rmse:0.01521	validation_0-mae:0.01157	validation_1-rmse:0.02542	validation_1-mae:0.01919
# [57]	validation_0-rmse:0.01516	validation_0-mae:0.01153	validation_1-rmse:0.02541	validation_1-mae:0.01918
# [58]	validation_0-rmse:0.01510	validation_0-mae:0.01148	validation_1-rmse:0.02540	validation_1-mae:0.01917
# [59]	validation_0-rmse:0.01502	validation_0-mae:0.01141	validation_1-rmse:0.02539	validation_1-mae:0.01916
# [60]	validation_0-rmse:0.01494	validation_0-mae:0.01135	validation_1-rmse:0.02539	validation_1-mae:0.01916
# [61]	validation_0-rmse:0.01489	validation_0-mae:0.01130	validation_1-rmse:0.02539	validation_1-mae:0.01915
# [62]	validation_0-rmse:0.01478	validation_0-mae:0.01122	validation_1-rmse:0.02538	validation_1-mae:0.01914
# [63]	validation_0-rmse:0.01467	validation_0-mae:0.01114	validation_1-rmse:0.02537	validation_1-mae:0.01914
# [64]	validation_0-rmse:0.01461	validation_0-mae:0.01108	validation_1-rmse:0.02536	validation_1-mae:0.01913
# [65]	validation_0-rmse:0.01455	validation_0-mae:0.01103	validation_1-rmse:0.02535	validation_1-mae:0.01912
# [66]	validation_0-rmse:0.01449	validation_0-mae:0.01098	validation_1-rmse:0.02535	validation_1-mae:0.01912
# [67]	validation_0-rmse:0.01442	validation_0-mae:0.01093	validation_1-rmse:0.02535	validation_1-mae:0.01912
# [68]	validation_0-rmse:0.01436	validation_0-mae:0.01088	validation_1-rmse:0.02534	validation_1-mae:0.01911
# [69]	validation_0-rmse:0.01430	validation_0-mae:0.01083	validation_1-rmse:0.02534	validation_1-mae:0.01911
# [70]	validation_0-rmse:0.01426	validation_0-mae:0.01079	validation_1-rmse:0.02533	validation_1-mae:0.01910
# [71]	validation_0-rmse:0.01419	validation_0-mae:0.01074	validation_1-rmse:0.02533	validation_1-mae:0.01910
# [72]	validation_0-rmse:0.01412	validation_0-mae:0.01069	validation_1-rmse:0.02533	validation_1-mae:0.01910
# [73]	validation_0-rmse:0.01408	validation_0-mae:0.01064	validation_1-rmse:0.02533	validation_1-mae:0.01909
# [74]	validation_0-rmse:0.01404	validation_0-mae:0.01061	validation_1-rmse:0.02533	validation_1-mae:0.01909
# [75]	validation_0-rmse:0.01399	validation_0-mae:0.01057	validation_1-rmse:0.02532	validation_1-mae:0.01909
# [76]	validation_0-rmse:0.01395	validation_0-mae:0.01054	validation_1-rmse:0.02532	validation_1-mae:0.01909
# [77]	validation_0-rmse:0.01386	validation_0-mae:0.01046	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [78]	validation_0-rmse:0.01379	validation_0-mae:0.01041	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [79]	validation_0-rmse:0.01374	validation_0-mae:0.01037	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [80]	validation_0-rmse:0.01370	validation_0-mae:0.01034	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [81]	validation_0-rmse:0.01368	validation_0-mae:0.01032	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [82]	validation_0-rmse:0.01366	validation_0-mae:0.01030	validation_1-rmse:0.02530	validation_1-mae:0.01907
# [83]	validation_0-rmse:0.01363	validation_0-mae:0.01027	validation_1-rmse:0.02530	validation_1-mae:0.01907
# [84]	validation_0-rmse:0.01358	validation_0-mae:0.01023	validation_1-rmse:0.02530	validation_1-mae:0.01907
# [85]	validation_0-rmse:0.01355	validation_0-mae:0.01021	validation_1-rmse:0.02530	validation_1-mae:0.01907
# [86]	validation_0-rmse:0.01353	validation_0-mae:0.01018	validation_1-rmse:0.02529	validation_1-mae:0.01906
# [87]	validation_0-rmse:0.01350	validation_0-mae:0.01016	validation_1-rmse:0.02529	validation_1-mae:0.01906
# [88]	validation_0-rmse:0.01346	validation_0-mae:0.01013	validation_1-rmse:0.02530	validation_1-mae:0.01906
# [89]	validation_0-rmse:0.01342	validation_0-mae:0.01009	validation_1-rmse:0.02529	validation_1-mae:0.01906
# [90]	validation_0-rmse:0.01335	validation_0-mae:0.01004	validation_1-rmse:0.02529	validation_1-mae:0.01906
# [91]	validation_0-rmse:0.01329	validation_0-mae:0.00999	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [92]	validation_0-rmse:0.01328	validation_0-mae:0.00998	validation_1-rmse:0.02528	validation_1-mae:0.01906
# [93]	validation_0-rmse:0.01324	validation_0-mae:0.00995	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [94]	validation_0-rmse:0.01315	validation_0-mae:0.00988	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [95]	validation_0-rmse:0.01311	validation_0-mae:0.00985	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [96]	validation_0-rmse:0.01305	validation_0-mae:0.00980	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [97]	validation_0-rmse:0.01303	validation_0-mae:0.00978	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [98]	validation_0-rmse:0.01300	validation_0-mae:0.00975	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [99]	validation_0-rmse:0.01294	validation_0-mae:0.00971	validation_1-rmse:0.02528	validation_1-mae:0.01905
# Features used for model training =  ['aspect', 'slope', 'NDMI', 'SR_B5', 'SAVI', 'EVI', 'NDVI', 'ST_B10', 'MNDWI', 'SR_B7', 'SR_B6', 'MSAVI']
# Number of principal components used for model training =  None
# MAE =  0.01905145125654723
# MSE =  0.0006392173732447036
# R2 Score =  0.9817844060490156
# Adjusted R2 Score =  0.9817634625664621

# %%
trained_model = training_results_threerivers_2022['estimator']

# %%
# splitting the test data to separate dependant and indepenedant variables .. will use y for a hidden prediction
X = test_df.drop('smi', axis = 1)
y = test_df['smi']

# %% [markdown]
# Prediction with no scaling in preprocessing

# %%
y_pred_threerivers21 = trained_model.predict(X)

# %%
r2_threerivers21 = r2_score(y, y_pred_threerivers21)
r2_threerivers21
# Out:
# 0.6726809150054167

# %%
# Train/test predictions with scaling
train_results_threerivers22_scale = train_test_eval_model(train_df, xgb_reg, features = features, scale = True, test_size= 0.2, n_pca = None)
# Out:
# XGBRegressor
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:0.17056	validation_0-mae:0.13989	validation_1-rmse:0.16912	validation_1-mae:0.13794
# [1]	validation_0-rmse:0.15406	validation_0-mae:0.12631	validation_1-rmse:0.15284	validation_1-mae:0.12465
# [2]	validation_0-rmse:0.13924	validation_0-mae:0.11410	validation_1-rmse:0.13821	validation_1-mae:0.11270
# [3]	validation_0-rmse:0.12592	validation_0-mae:0.10312	validation_1-rmse:0.12509	validation_1-mae:0.10198
# [4]	validation_0-rmse:0.11397	validation_0-mae:0.09326	validation_1-rmse:0.11336	validation_1-mae:0.09236
# [5]	validation_0-rmse:0.10325	validation_0-mae:0.08440	validation_1-rmse:0.10284	validation_1-mae:0.08372
# [6]	validation_0-rmse:0.09361	validation_0-mae:0.07645	validation_1-rmse:0.09345	validation_1-mae:0.07602
# [7]	validation_0-rmse:0.08498	validation_0-mae:0.06933	validation_1-rmse:0.08505	validation_1-mae:0.06913
# [8]	validation_0-rmse:0.07723	validation_0-mae:0.06295	validation_1-rmse:0.07757	validation_1-mae:0.06298
# [9]	validation_0-rmse:0.07029	validation_0-mae:0.05722	validation_1-rmse:0.07089	validation_1-mae:0.05749
# [10]	validation_0-rmse:0.06408	validation_0-mae:0.05210	validation_1-rmse:0.06494	validation_1-mae:0.05260
# [11]	validation_0-rmse:0.05855	validation_0-mae:0.04754	validation_1-rmse:0.05969	validation_1-mae:0.04828
# [12]	validation_0-rmse:0.05360	validation_0-mae:0.04347	validation_1-rmse:0.05505	validation_1-mae:0.04445
# [13]	validation_0-rmse:0.04919	validation_0-mae:0.03984	validation_1-rmse:0.05096	validation_1-mae:0.04108
# [14]	validation_0-rmse:0.04527	validation_0-mae:0.03662	validation_1-rmse:0.04736	validation_1-mae:0.03810
# [15]	validation_0-rmse:0.04178	validation_0-mae:0.03375	validation_1-rmse:0.04420	validation_1-mae:0.03548
# [16]	validation_0-rmse:0.03870	validation_0-mae:0.03121	validation_1-rmse:0.04149	validation_1-mae:0.03325
# [17]	validation_0-rmse:0.03598	validation_0-mae:0.02898	validation_1-rmse:0.03911	validation_1-mae:0.03126
# [18]	validation_0-rmse:0.03356	validation_0-mae:0.02701	validation_1-rmse:0.03706	validation_1-mae:0.02954
# [19]	validation_0-rmse:0.03143	validation_0-mae:0.02525	validation_1-rmse:0.03531	validation_1-mae:0.02807
# [20]	validation_0-rmse:0.02958	validation_0-mae:0.02372	validation_1-rmse:0.03381	validation_1-mae:0.02681
# [21]	validation_0-rmse:0.02795	validation_0-mae:0.02237	validation_1-rmse:0.03251	validation_1-mae:0.02573
# [22]	validation_0-rmse:0.02654	validation_0-mae:0.02120	validation_1-rmse:0.03140	validation_1-mae:0.02478
# [23]	validation_0-rmse:0.02528	validation_0-mae:0.02016	validation_1-rmse:0.03048	validation_1-mae:0.02398
# [24]	validation_0-rmse:0.02420	validation_0-mae:0.01926	validation_1-rmse:0.02971	validation_1-mae:0.02329
# [25]	validation_0-rmse:0.02324	validation_0-mae:0.01846	validation_1-rmse:0.02905	validation_1-mae:0.02269
# [26]	validation_0-rmse:0.02241	validation_0-mae:0.01776	validation_1-rmse:0.02850	validation_1-mae:0.02218
# [27]	validation_0-rmse:0.02167	validation_0-mae:0.01713	validation_1-rmse:0.02803	validation_1-mae:0.02174
# [28]	validation_0-rmse:0.02102	validation_0-mae:0.01659	validation_1-rmse:0.02764	validation_1-mae:0.02137
# [29]	validation_0-rmse:0.02046	validation_0-mae:0.01610	validation_1-rmse:0.02732	validation_1-mae:0.02106
# [30]	validation_0-rmse:0.01994	validation_0-mae:0.01566	validation_1-rmse:0.02703	validation_1-mae:0.02078
# [31]	validation_0-rmse:0.01949	validation_0-mae:0.01527	validation_1-rmse:0.02679	validation_1-mae:0.02055
# [32]	validation_0-rmse:0.01912	validation_0-mae:0.01494	validation_1-rmse:0.02659	validation_1-mae:0.02035
# [33]	validation_0-rmse:0.01878	validation_0-mae:0.01465	validation_1-rmse:0.02643	validation_1-mae:0.02020
# [34]	validation_0-rmse:0.01847	validation_0-mae:0.01438	validation_1-rmse:0.02628	validation_1-mae:0.02005
# [35]	validation_0-rmse:0.01821	validation_0-mae:0.01415	validation_1-rmse:0.02617	validation_1-mae:0.01994
# [36]	validation_0-rmse:0.01797	validation_0-mae:0.01394	validation_1-rmse:0.02607	validation_1-mae:0.01983
# [37]	validation_0-rmse:0.01775	validation_0-mae:0.01375	validation_1-rmse:0.02597	validation_1-mae:0.01973
# [38]	validation_0-rmse:0.01754	validation_0-mae:0.01356	validation_1-rmse:0.02590	validation_1-mae:0.01965
# [39]	validation_0-rmse:0.01736	validation_0-mae:0.01340	validation_1-rmse:0.02585	validation_1-mae:0.01958
# [40]	validation_0-rmse:0.01719	validation_0-mae:0.01326	validation_1-rmse:0.02580	validation_1-mae:0.01952
# [41]	validation_0-rmse:0.01702	validation_0-mae:0.01311	validation_1-rmse:0.02574	validation_1-mae:0.01947
# [42]	validation_0-rmse:0.01688	validation_0-mae:0.01299	validation_1-rmse:0.02571	validation_1-mae:0.01943
# [43]	validation_0-rmse:0.01675	validation_0-mae:0.01288	validation_1-rmse:0.02568	validation_1-mae:0.01940
# [44]	validation_0-rmse:0.01659	validation_0-mae:0.01275	validation_1-rmse:0.02565	validation_1-mae:0.01937
# [45]	validation_0-rmse:0.01649	validation_0-mae:0.01266	validation_1-rmse:0.02563	validation_1-mae:0.01934
# [46]	validation_0-rmse:0.01638	validation_0-mae:0.01257	validation_1-rmse:0.02560	validation_1-mae:0.01931
# [47]	validation_0-rmse:0.01627	validation_0-mae:0.01247	validation_1-rmse:0.02559	validation_1-mae:0.01929
# [48]	validation_0-rmse:0.01616	validation_0-mae:0.01238	validation_1-rmse:0.02556	validation_1-mae:0.01927
# [49]	validation_0-rmse:0.01605	validation_0-mae:0.01228	validation_1-rmse:0.02555	validation_1-mae:0.01926
# [50]	validation_0-rmse:0.01596	validation_0-mae:0.01221	validation_1-rmse:0.02553	validation_1-mae:0.01923
# [51]	validation_0-rmse:0.01588	validation_0-mae:0.01214	validation_1-rmse:0.02552	validation_1-mae:0.01921
# [52]	validation_0-rmse:0.01579	validation_0-mae:0.01206	validation_1-rmse:0.02551	validation_1-mae:0.01920
# [53]	validation_0-rmse:0.01570	validation_0-mae:0.01199	validation_1-rmse:0.02550	validation_1-mae:0.01919
# [54]	validation_0-rmse:0.01561	validation_0-mae:0.01192	validation_1-rmse:0.02548	validation_1-mae:0.01917
# [55]	validation_0-rmse:0.01553	validation_0-mae:0.01184	validation_1-rmse:0.02548	validation_1-mae:0.01916
# [56]	validation_0-rmse:0.01544	validation_0-mae:0.01177	validation_1-rmse:0.02547	validation_1-mae:0.01916
# [57]	validation_0-rmse:0.01538	validation_0-mae:0.01171	validation_1-rmse:0.02547	validation_1-mae:0.01915
# [58]	validation_0-rmse:0.01529	validation_0-mae:0.01164	validation_1-rmse:0.02546	validation_1-mae:0.01914
# [59]	validation_0-rmse:0.01522	validation_0-mae:0.01159	validation_1-rmse:0.02545	validation_1-mae:0.01913
# [60]	validation_0-rmse:0.01512	validation_0-mae:0.01151	validation_1-rmse:0.02544	validation_1-mae:0.01912
# [61]	validation_0-rmse:0.01503	validation_0-mae:0.01144	validation_1-rmse:0.02543	validation_1-mae:0.01912
# [62]	validation_0-rmse:0.01497	validation_0-mae:0.01139	validation_1-rmse:0.02544	validation_1-mae:0.01912
# [63]	validation_0-rmse:0.01490	validation_0-mae:0.01133	validation_1-rmse:0.02543	validation_1-mae:0.01911
# [64]	validation_0-rmse:0.01484	validation_0-mae:0.01128	validation_1-rmse:0.02541	validation_1-mae:0.01910
# [65]	validation_0-rmse:0.01477	validation_0-mae:0.01123	validation_1-rmse:0.02540	validation_1-mae:0.01909
# [66]	validation_0-rmse:0.01469	validation_0-mae:0.01116	validation_1-rmse:0.02542	validation_1-mae:0.01909
# [67]	validation_0-rmse:0.01462	validation_0-mae:0.01111	validation_1-rmse:0.02541	validation_1-mae:0.01909
# [68]	validation_0-rmse:0.01460	validation_0-mae:0.01109	validation_1-rmse:0.02540	validation_1-mae:0.01909
# [69]	validation_0-rmse:0.01454	validation_0-mae:0.01105	validation_1-rmse:0.02540	validation_1-mae:0.01908
# [70]	validation_0-rmse:0.01446	validation_0-mae:0.01099	validation_1-rmse:0.02540	validation_1-mae:0.01909
# [71]	validation_0-rmse:0.01443	validation_0-mae:0.01095	validation_1-rmse:0.02539	validation_1-mae:0.01908
# [72]	validation_0-rmse:0.01434	validation_0-mae:0.01089	validation_1-rmse:0.02540	validation_1-mae:0.01908
# [73]	validation_0-rmse:0.01429	validation_0-mae:0.01085	validation_1-rmse:0.02539	validation_1-mae:0.01907
# [74]	validation_0-rmse:0.01423	validation_0-mae:0.01080	validation_1-rmse:0.02539	validation_1-mae:0.01907
# [75]	validation_0-rmse:0.01418	validation_0-mae:0.01076	validation_1-rmse:0.02539	validation_1-mae:0.01907
# [76]	validation_0-rmse:0.01416	validation_0-mae:0.01074	validation_1-rmse:0.02539	validation_1-mae:0.01907
# [77]	validation_0-rmse:0.01411	validation_0-mae:0.01070	validation_1-rmse:0.02539	validation_1-mae:0.01907
# [78]	validation_0-rmse:0.01408	validation_0-mae:0.01067	validation_1-rmse:0.02539	validation_1-mae:0.01907
# [79]	validation_0-rmse:0.01404	validation_0-mae:0.01064	validation_1-rmse:0.02539	validation_1-mae:0.01907
# [80]	validation_0-rmse:0.01400	validation_0-mae:0.01061	validation_1-rmse:0.02538	validation_1-mae:0.01906
# [81]	validation_0-rmse:0.01398	validation_0-mae:0.01058	validation_1-rmse:0.02538	validation_1-mae:0.01906
# [82]	validation_0-rmse:0.01390	validation_0-mae:0.01052	validation_1-rmse:0.02538	validation_1-mae:0.01905
# [83]	validation_0-rmse:0.01384	validation_0-mae:0.01047	validation_1-rmse:0.02537	validation_1-mae:0.01905
# [84]	validation_0-rmse:0.01381	validation_0-mae:0.01045	validation_1-rmse:0.02537	validation_1-mae:0.01905
# [85]	validation_0-rmse:0.01375	validation_0-mae:0.01040	validation_1-rmse:0.02538	validation_1-mae:0.01905
# [86]	validation_0-rmse:0.01373	validation_0-mae:0.01037	validation_1-rmse:0.02538	validation_1-mae:0.01905
# [87]	validation_0-rmse:0.01368	validation_0-mae:0.01034	validation_1-rmse:0.02537	validation_1-mae:0.01905
# [88]	validation_0-rmse:0.01361	validation_0-mae:0.01028	validation_1-rmse:0.02537	validation_1-mae:0.01905
# [89]	validation_0-rmse:0.01357	validation_0-mae:0.01025	validation_1-rmse:0.02537	validation_1-mae:0.01905
# [90]	validation_0-rmse:0.01355	validation_0-mae:0.01022	validation_1-rmse:0.02537	validation_1-mae:0.01905
# [91]	validation_0-rmse:0.01351	validation_0-mae:0.01019	validation_1-rmse:0.02536	validation_1-mae:0.01904
# [92]	validation_0-rmse:0.01346	validation_0-mae:0.01016	validation_1-rmse:0.02536	validation_1-mae:0.01904
# [93]	validation_0-rmse:0.01342	validation_0-mae:0.01012	validation_1-rmse:0.02536	validation_1-mae:0.01904
# [94]	validation_0-rmse:0.01339	validation_0-mae:0.01010	validation_1-rmse:0.02536	validation_1-mae:0.01905
# [95]	validation_0-rmse:0.01332	validation_0-mae:0.01004	validation_1-rmse:0.02536	validation_1-mae:0.01904
# [96]	validation_0-rmse:0.01327	validation_0-mae:0.01000	validation_1-rmse:0.02535	validation_1-mae:0.01903
# [97]	validation_0-rmse:0.01326	validation_0-mae:0.00999	validation_1-rmse:0.02535	validation_1-mae:0.01903
# [98]	validation_0-rmse:0.01319	validation_0-mae:0.00993	validation_1-rmse:0.02535	validation_1-mae:0.01903
# [99]	validation_0-rmse:0.01315	validation_0-mae:0.00990	validation_1-rmse:0.02534	validation_1-mae:0.01903
# Features used for model training =  ['aspect', 'slope', 'NDMI', 'SR_B5', 'SAVI', 'EVI', 'NDVI', 'ST_B10', 'MNDWI', 'SR_B7', 'SR_B6', 'MSAVI']
# Number of principal components used for model training =  None
# MAE =  0.019029701749849907
# MSE =  0.0006422951421855844
# R2 Score =  0.9816807042425202
# Adjusted R2 Score =  0.9816543676486433

# %%
trained_model_scale = train_results_threerivers22_scale['estimator']

# %%
scaled_X = train_results_threerivers22_scale['scaler'].transform(X.values)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Prediction with scaling in preprocessing

# %%
y_pred_threerivers21_scale = trained_model_scale.predict(scaled_X)

# %%
r2_threerivers21_scale = r2_score(y, y_pred_threerivers21_scale)
r2_threerivers21_scale
# Out:
# 0.6728824954203343

# %% [markdown]
# ###5- Train model on ThreeRivers22 data and test on Mariposa21 data

# %%
test_df = pd.read_csv('/content/drive/mariposa_2021.csv')

# %%
test_df = test_df[['aspect','slope','NDMI'
                                 ,'SR_B5','SAVI','EVI','NDVI','ST_B10'
                                 ,'MNDWI','SR_B7','SR_B6','MSAVI','smi']]

# %%
X = test_df.drop('smi', axis = 1)
y = test_df['smi']

# %%
training_results_threerivers_2022 = train_test_eval_model(train_df, xgb_reg, features = features, scale = False, test_size= 0.25, n_pca = None)
# Out:
# XGBRegressor
# [0]	validation_0-rmse:0.17064	validation_0-mae:0.13990	validation_1-rmse:0.16922	validation_1-mae:0.13824
# [1]	validation_0-rmse:0.15413	validation_0-mae:0.12631	validation_1-rmse:0.15290	validation_1-mae:0.12488
# [2]	validation_0-rmse:0.13931	validation_0-mae:0.11411	validation_1-rmse:0.13828	validation_1-mae:0.11290
# [3]	validation_0-rmse:0.12598	validation_0-mae:0.10312	validation_1-rmse:0.12518	validation_1-mae:0.10217
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:0.11403	validation_0-mae:0.09326	validation_1-rmse:0.11345	validation_1-mae:0.09254
# [5]	validation_0-rmse:0.10330	validation_0-mae:0.08441	validation_1-rmse:0.10295	validation_1-mae:0.08390
# [6]	validation_0-rmse:0.09365	validation_0-mae:0.07645	validation_1-rmse:0.09352	validation_1-mae:0.07617
# [7]	validation_0-rmse:0.08502	validation_0-mae:0.06933	validation_1-rmse:0.08512	validation_1-mae:0.06928
# [8]	validation_0-rmse:0.07726	validation_0-mae:0.06293	validation_1-rmse:0.07758	validation_1-mae:0.06309
# [9]	validation_0-rmse:0.07031	validation_0-mae:0.05720	validation_1-rmse:0.07090	validation_1-mae:0.05761
# [10]	validation_0-rmse:0.06409	validation_0-mae:0.05207	validation_1-rmse:0.06498	validation_1-mae:0.05275
# [11]	validation_0-rmse:0.05856	validation_0-mae:0.04750	validation_1-rmse:0.05971	validation_1-mae:0.04842
# [12]	validation_0-rmse:0.05361	validation_0-mae:0.04343	validation_1-rmse:0.05507	validation_1-mae:0.04460
# [13]	validation_0-rmse:0.04920	validation_0-mae:0.03981	validation_1-rmse:0.05096	validation_1-mae:0.04122
# [14]	validation_0-rmse:0.04525	validation_0-mae:0.03657	validation_1-rmse:0.04737	validation_1-mae:0.03826
# [15]	validation_0-rmse:0.04176	validation_0-mae:0.03370	validation_1-rmse:0.04422	validation_1-mae:0.03565
# [16]	validation_0-rmse:0.03867	validation_0-mae:0.03116	validation_1-rmse:0.04148	validation_1-mae:0.03338
# [17]	validation_0-rmse:0.03594	validation_0-mae:0.02893	validation_1-rmse:0.03907	validation_1-mae:0.03137
# [18]	validation_0-rmse:0.03352	validation_0-mae:0.02695	validation_1-rmse:0.03701	validation_1-mae:0.02964
# [19]	validation_0-rmse:0.03139	validation_0-mae:0.02519	validation_1-rmse:0.03524	validation_1-mae:0.02815
# [20]	validation_0-rmse:0.02952	validation_0-mae:0.02365	validation_1-rmse:0.03374	validation_1-mae:0.02687
# [21]	validation_0-rmse:0.02788	validation_0-mae:0.02230	validation_1-rmse:0.03245	validation_1-mae:0.02577
# [22]	validation_0-rmse:0.02645	validation_0-mae:0.02111	validation_1-rmse:0.03133	validation_1-mae:0.02481
# [23]	validation_0-rmse:0.02519	validation_0-mae:0.02007	validation_1-rmse:0.03040	validation_1-mae:0.02399
# [24]	validation_0-rmse:0.02409	validation_0-mae:0.01916	validation_1-rmse:0.02961	validation_1-mae:0.02330
# [25]	validation_0-rmse:0.02311	validation_0-mae:0.01834	validation_1-rmse:0.02893	validation_1-mae:0.02269
# [26]	validation_0-rmse:0.02228	validation_0-mae:0.01765	validation_1-rmse:0.02839	validation_1-mae:0.02218
# [27]	validation_0-rmse:0.02153	validation_0-mae:0.01701	validation_1-rmse:0.02792	validation_1-mae:0.02175
# [28]	validation_0-rmse:0.02088	validation_0-mae:0.01646	validation_1-rmse:0.02753	validation_1-mae:0.02137
# [29]	validation_0-rmse:0.02030	validation_0-mae:0.01596	validation_1-rmse:0.02721	validation_1-mae:0.02106
# [30]	validation_0-rmse:0.01979	validation_0-mae:0.01553	validation_1-rmse:0.02692	validation_1-mae:0.02077
# [31]	validation_0-rmse:0.01936	validation_0-mae:0.01515	validation_1-rmse:0.02669	validation_1-mae:0.02054
# [32]	validation_0-rmse:0.01897	validation_0-mae:0.01482	validation_1-rmse:0.02649	validation_1-mae:0.02034
# [33]	validation_0-rmse:0.01865	validation_0-mae:0.01454	validation_1-rmse:0.02634	validation_1-mae:0.02019
# [34]	validation_0-rmse:0.01833	validation_0-mae:0.01426	validation_1-rmse:0.02620	validation_1-mae:0.02004
# [35]	validation_0-rmse:0.01805	validation_0-mae:0.01402	validation_1-rmse:0.02609	validation_1-mae:0.01992
# [36]	validation_0-rmse:0.01783	validation_0-mae:0.01382	validation_1-rmse:0.02599	validation_1-mae:0.01982
# [37]	validation_0-rmse:0.01762	validation_0-mae:0.01363	validation_1-rmse:0.02590	validation_1-mae:0.01973
# [38]	validation_0-rmse:0.01741	validation_0-mae:0.01345	validation_1-rmse:0.02583	validation_1-mae:0.01965
# [39]	validation_0-rmse:0.01719	validation_0-mae:0.01327	validation_1-rmse:0.02577	validation_1-mae:0.01958
# [40]	validation_0-rmse:0.01703	validation_0-mae:0.01312	validation_1-rmse:0.02572	validation_1-mae:0.01952
# [41]	validation_0-rmse:0.01687	validation_0-mae:0.01298	validation_1-rmse:0.02568	validation_1-mae:0.01948
# [42]	validation_0-rmse:0.01672	validation_0-mae:0.01285	validation_1-rmse:0.02564	validation_1-mae:0.01944
# [43]	validation_0-rmse:0.01657	validation_0-mae:0.01273	validation_1-rmse:0.02560	validation_1-mae:0.01940
# [44]	validation_0-rmse:0.01643	validation_0-mae:0.01261	validation_1-rmse:0.02557	validation_1-mae:0.01936
# [45]	validation_0-rmse:0.01630	validation_0-mae:0.01249	validation_1-rmse:0.02555	validation_1-mae:0.01933
# [46]	validation_0-rmse:0.01618	validation_0-mae:0.01239	validation_1-rmse:0.02553	validation_1-mae:0.01931
# [47]	validation_0-rmse:0.01606	validation_0-mae:0.01229	validation_1-rmse:0.02551	validation_1-mae:0.01929
# [48]	validation_0-rmse:0.01598	validation_0-mae:0.01222	validation_1-rmse:0.02550	validation_1-mae:0.01927
# [49]	validation_0-rmse:0.01587	validation_0-mae:0.01213	validation_1-rmse:0.02548	validation_1-mae:0.01925
# [50]	validation_0-rmse:0.01577	validation_0-mae:0.01204	validation_1-rmse:0.02547	validation_1-mae:0.01924
# [51]	validation_0-rmse:0.01569	validation_0-mae:0.01197	validation_1-rmse:0.02546	validation_1-mae:0.01922
# [52]	validation_0-rmse:0.01558	validation_0-mae:0.01188	validation_1-rmse:0.02544	validation_1-mae:0.01921
# [53]	validation_0-rmse:0.01548	validation_0-mae:0.01180	validation_1-rmse:0.02544	validation_1-mae:0.01921
# [54]	validation_0-rmse:0.01541	validation_0-mae:0.01174	validation_1-rmse:0.02543	validation_1-mae:0.01920
# [55]	validation_0-rmse:0.01532	validation_0-mae:0.01166	validation_1-rmse:0.02542	validation_1-mae:0.01919
# [56]	validation_0-rmse:0.01521	validation_0-mae:0.01157	validation_1-rmse:0.02542	validation_1-mae:0.01919
# [57]	validation_0-rmse:0.01516	validation_0-mae:0.01153	validation_1-rmse:0.02541	validation_1-mae:0.01918
# [58]	validation_0-rmse:0.01510	validation_0-mae:0.01148	validation_1-rmse:0.02540	validation_1-mae:0.01917
# [59]	validation_0-rmse:0.01502	validation_0-mae:0.01141	validation_1-rmse:0.02539	validation_1-mae:0.01916
# [60]	validation_0-rmse:0.01494	validation_0-mae:0.01135	validation_1-rmse:0.02539	validation_1-mae:0.01916
# [61]	validation_0-rmse:0.01489	validation_0-mae:0.01130	validation_1-rmse:0.02539	validation_1-mae:0.01915
# [62]	validation_0-rmse:0.01478	validation_0-mae:0.01122	validation_1-rmse:0.02538	validation_1-mae:0.01914
# [63]	validation_0-rmse:0.01467	validation_0-mae:0.01114	validation_1-rmse:0.02537	validation_1-mae:0.01914
# [64]	validation_0-rmse:0.01461	validation_0-mae:0.01108	validation_1-rmse:0.02536	validation_1-mae:0.01913
# [65]	validation_0-rmse:0.01455	validation_0-mae:0.01103	validation_1-rmse:0.02535	validation_1-mae:0.01912
# [66]	validation_0-rmse:0.01449	validation_0-mae:0.01098	validation_1-rmse:0.02535	validation_1-mae:0.01912
# [67]	validation_0-rmse:0.01442	validation_0-mae:0.01093	validation_1-rmse:0.02535	validation_1-mae:0.01912
# [68]	validation_0-rmse:0.01436	validation_0-mae:0.01088	validation_1-rmse:0.02534	validation_1-mae:0.01911
# [69]	validation_0-rmse:0.01430	validation_0-mae:0.01083	validation_1-rmse:0.02534	validation_1-mae:0.01911
# [70]	validation_0-rmse:0.01426	validation_0-mae:0.01079	validation_1-rmse:0.02533	validation_1-mae:0.01910
# [71]	validation_0-rmse:0.01419	validation_0-mae:0.01074	validation_1-rmse:0.02533	validation_1-mae:0.01910
# [72]	validation_0-rmse:0.01412	validation_0-mae:0.01069	validation_1-rmse:0.02533	validation_1-mae:0.01910
# [73]	validation_0-rmse:0.01408	validation_0-mae:0.01064	validation_1-rmse:0.02533	validation_1-mae:0.01909
# [74]	validation_0-rmse:0.01404	validation_0-mae:0.01061	validation_1-rmse:0.02533	validation_1-mae:0.01909
# [75]	validation_0-rmse:0.01399	validation_0-mae:0.01057	validation_1-rmse:0.02532	validation_1-mae:0.01909
# [76]	validation_0-rmse:0.01395	validation_0-mae:0.01054	validation_1-rmse:0.02532	validation_1-mae:0.01909
# [77]	validation_0-rmse:0.01386	validation_0-mae:0.01046	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [78]	validation_0-rmse:0.01379	validation_0-mae:0.01041	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [79]	validation_0-rmse:0.01374	validation_0-mae:0.01037	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [80]	validation_0-rmse:0.01370	validation_0-mae:0.01034	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [81]	validation_0-rmse:0.01368	validation_0-mae:0.01032	validation_1-rmse:0.02531	validation_1-mae:0.01908
# [82]	validation_0-rmse:0.01366	validation_0-mae:0.01030	validation_1-rmse:0.02530	validation_1-mae:0.01907
# [83]	validation_0-rmse:0.01363	validation_0-mae:0.01027	validation_1-rmse:0.02530	validation_1-mae:0.01907
# [84]	validation_0-rmse:0.01358	validation_0-mae:0.01023	validation_1-rmse:0.02530	validation_1-mae:0.01907
# [85]	validation_0-rmse:0.01355	validation_0-mae:0.01021	validation_1-rmse:0.02530	validation_1-mae:0.01907
# [86]	validation_0-rmse:0.01353	validation_0-mae:0.01018	validation_1-rmse:0.02529	validation_1-mae:0.01906
# [87]	validation_0-rmse:0.01350	validation_0-mae:0.01016	validation_1-rmse:0.02529	validation_1-mae:0.01906
# [88]	validation_0-rmse:0.01346	validation_0-mae:0.01013	validation_1-rmse:0.02530	validation_1-mae:0.01906
# [89]	validation_0-rmse:0.01342	validation_0-mae:0.01009	validation_1-rmse:0.02529	validation_1-mae:0.01906
# [90]	validation_0-rmse:0.01335	validation_0-mae:0.01004	validation_1-rmse:0.02529	validation_1-mae:0.01906
# [91]	validation_0-rmse:0.01329	validation_0-mae:0.00999	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [92]	validation_0-rmse:0.01328	validation_0-mae:0.00998	validation_1-rmse:0.02528	validation_1-mae:0.01906
# [93]	validation_0-rmse:0.01324	validation_0-mae:0.00995	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [94]	validation_0-rmse:0.01315	validation_0-mae:0.00988	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [95]	validation_0-rmse:0.01311	validation_0-mae:0.00985	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [96]	validation_0-rmse:0.01305	validation_0-mae:0.00980	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [97]	validation_0-rmse:0.01303	validation_0-mae:0.00978	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [98]	validation_0-rmse:0.01300	validation_0-mae:0.00975	validation_1-rmse:0.02528	validation_1-mae:0.01905
# [99]	validation_0-rmse:0.01294	validation_0-mae:0.00971	validation_1-rmse:0.02528	validation_1-mae:0.01905
# Features used for model training =  ['aspect', 'slope', 'NDMI', 'SR_B5', 'SAVI', 'EVI', 'NDVI', 'ST_B10', 'MNDWI', 'SR_B7', 'SR_B6', 'MSAVI']
# Number of principal components used for model training =  None
# MAE =  0.01905145125654723
# MSE =  0.0006392173732447036
# R2 Score =  0.9817844060490156
# Adjusted R2 Score =  0.9817634625664621

# %% [markdown]
# Prediction with no scaling in preprocessing

# %%
y_pred_mariposa21 = trained_model.predict(X)

# %%
r2_Mariposa21 = r2_score(y, y_pred_mariposa21)
r2_Mariposa21
# Out:
# -1.297874833163192

# %% [markdown]
# ###6- Train model on  Mariposa21 and test on  Mariposa22

# %%
train_df = pd.read_csv('/content/drive/mariposa_2021.csv')
test_df = pd.read_csv('/content/drive/mariposa_2022.csv')

# %%
train_df = train_df[['aspect', 'slope', 'EVI', 'MNDWI', 'MSAVI', 'NDMI','NDVI', 'SAVI', 'SR_B5', 'SR_B6', 'SR_B7','ST_B10','smi']]
test_df = test_df[['aspect', 'slope', 'EVI', 'MNDWI', 'MSAVI', 'NDMI','NDVI', 'SAVI', 'SR_B5', 'SR_B6', 'SR_B7','ST_B10','smi']]

# %%
# splitting train_df to train and val
X = train_df.drop('smi', axis = 1)
y = train_df['smi']

# %%
features = list(X.columns)

# %%
train_results_mariposa21 = train_test_eval_model(train_df, xgb_reg, features = features, scale = False, test_size= 0.25, n_pca = None)
# Out:
# XGBRegressor
# [0]	validation_0-rmse:0.12168	validation_0-mae:0.09370	validation_1-rmse:0.12302	validation_1-mae:0.09507
# [1]	validation_0-rmse:0.11238	validation_0-mae:0.08636	validation_1-rmse:0.11409	validation_1-mae:0.08794
# [2]	validation_0-rmse:0.10412	validation_0-mae:0.07986	validation_1-rmse:0.10627	validation_1-mae:0.08169
# [3]	validation_0-rmse:0.09688	validation_0-mae:0.07416	validation_1-rmse:0.09941	validation_1-mae:0.07623
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:0.09043	validation_0-mae:0.06910	validation_1-rmse:0.09342	validation_1-mae:0.07146
# [5]	validation_0-rmse:0.08476	validation_0-mae:0.06465	validation_1-rmse:0.08820	validation_1-mae:0.06733
# [6]	validation_0-rmse:0.07976	validation_0-mae:0.06072	validation_1-rmse:0.08368	validation_1-mae:0.06371
# [7]	validation_0-rmse:0.07535	validation_0-mae:0.05725	validation_1-rmse:0.07981	validation_1-mae:0.06058
# [8]	validation_0-rmse:0.07148	validation_0-mae:0.05418	validation_1-rmse:0.07644	validation_1-mae:0.05781
# [9]	validation_0-rmse:0.06812	validation_0-mae:0.05149	validation_1-rmse:0.07361	validation_1-mae:0.05543
# [10]	validation_0-rmse:0.06514	validation_0-mae:0.04911	validation_1-rmse:0.07115	validation_1-mae:0.05335
# [11]	validation_0-rmse:0.06257	validation_0-mae:0.04703	validation_1-rmse:0.06909	validation_1-mae:0.05159
# [12]	validation_0-rmse:0.06027	validation_0-mae:0.04517	validation_1-rmse:0.06737	validation_1-mae:0.05008
# [13]	validation_0-rmse:0.05823	validation_0-mae:0.04352	validation_1-rmse:0.06579	validation_1-mae:0.04869
# [14]	validation_0-rmse:0.05639	validation_0-mae:0.04204	validation_1-rmse:0.06451	validation_1-mae:0.04754
# [15]	validation_0-rmse:0.05483	validation_0-mae:0.04077	validation_1-rmse:0.06342	validation_1-mae:0.04654
# [16]	validation_0-rmse:0.05341	validation_0-mae:0.03960	validation_1-rmse:0.06251	validation_1-mae:0.04570
# [17]	validation_0-rmse:0.05214	validation_0-mae:0.03855	validation_1-rmse:0.06171	validation_1-mae:0.04494
# [18]	validation_0-rmse:0.05103	validation_0-mae:0.03762	validation_1-rmse:0.06102	validation_1-mae:0.04429
# [19]	validation_0-rmse:0.05008	validation_0-mae:0.03683	validation_1-rmse:0.06046	validation_1-mae:0.04375
# [20]	validation_0-rmse:0.04915	validation_0-mae:0.03607	validation_1-rmse:0.05991	validation_1-mae:0.04321
# [21]	validation_0-rmse:0.04837	validation_0-mae:0.03543	validation_1-rmse:0.05948	validation_1-mae:0.04279
# [22]	validation_0-rmse:0.04767	validation_0-mae:0.03485	validation_1-rmse:0.05907	validation_1-mae:0.04239
# [23]	validation_0-rmse:0.04701	validation_0-mae:0.03432	validation_1-rmse:0.05874	validation_1-mae:0.04205
# [24]	validation_0-rmse:0.04640	validation_0-mae:0.03383	validation_1-rmse:0.05841	validation_1-mae:0.04176
# [25]	validation_0-rmse:0.04582	validation_0-mae:0.03336	validation_1-rmse:0.05816	validation_1-mae:0.04151
# [26]	validation_0-rmse:0.04530	validation_0-mae:0.03295	validation_1-rmse:0.05793	validation_1-mae:0.04129
# [27]	validation_0-rmse:0.04483	validation_0-mae:0.03257	validation_1-rmse:0.05773	validation_1-mae:0.04111
# [28]	validation_0-rmse:0.04437	validation_0-mae:0.03222	validation_1-rmse:0.05753	validation_1-mae:0.04092
# [29]	validation_0-rmse:0.04396	validation_0-mae:0.03190	validation_1-rmse:0.05737	validation_1-mae:0.04077
# [30]	validation_0-rmse:0.04349	validation_0-mae:0.03155	validation_1-rmse:0.05717	validation_1-mae:0.04060
# [31]	validation_0-rmse:0.04312	validation_0-mae:0.03128	validation_1-rmse:0.05703	validation_1-mae:0.04046
# [32]	validation_0-rmse:0.04267	validation_0-mae:0.03095	validation_1-rmse:0.05686	validation_1-mae:0.04032
# [33]	validation_0-rmse:0.04226	validation_0-mae:0.03066	validation_1-rmse:0.05671	validation_1-mae:0.04018
# [34]	validation_0-rmse:0.04187	validation_0-mae:0.03039	validation_1-rmse:0.05657	validation_1-mae:0.04007
# [35]	validation_0-rmse:0.04151	validation_0-mae:0.03014	validation_1-rmse:0.05643	validation_1-mae:0.03997
# [36]	validation_0-rmse:0.04122	validation_0-mae:0.02993	validation_1-rmse:0.05636	validation_1-mae:0.03991
# [37]	validation_0-rmse:0.04087	validation_0-mae:0.02969	validation_1-rmse:0.05626	validation_1-mae:0.03984
# [38]	validation_0-rmse:0.04055	validation_0-mae:0.02947	validation_1-rmse:0.05617	validation_1-mae:0.03978
# [39]	validation_0-rmse:0.04025	validation_0-mae:0.02925	validation_1-rmse:0.05608	validation_1-mae:0.03971
# [40]	validation_0-rmse:0.04000	validation_0-mae:0.02907	validation_1-rmse:0.05601	validation_1-mae:0.03966
# [41]	validation_0-rmse:0.03970	validation_0-mae:0.02887	validation_1-rmse:0.05596	validation_1-mae:0.03961
# [42]	validation_0-rmse:0.03941	validation_0-mae:0.02867	validation_1-rmse:0.05586	validation_1-mae:0.03954
# [43]	validation_0-rmse:0.03909	validation_0-mae:0.02846	validation_1-rmse:0.05579	validation_1-mae:0.03948
# [44]	validation_0-rmse:0.03879	validation_0-mae:0.02825	validation_1-rmse:0.05573	validation_1-mae:0.03943
# [45]	validation_0-rmse:0.03855	validation_0-mae:0.02809	validation_1-rmse:0.05566	validation_1-mae:0.03939
# [46]	validation_0-rmse:0.03829	validation_0-mae:0.02791	validation_1-rmse:0.05559	validation_1-mae:0.03935
# [47]	validation_0-rmse:0.03808	validation_0-mae:0.02777	validation_1-rmse:0.05553	validation_1-mae:0.03931
# [48]	validation_0-rmse:0.03784	validation_0-mae:0.02760	validation_1-rmse:0.05548	validation_1-mae:0.03927
# [49]	validation_0-rmse:0.03759	validation_0-mae:0.02743	validation_1-rmse:0.05544	validation_1-mae:0.03924
# [50]	validation_0-rmse:0.03739	validation_0-mae:0.02729	validation_1-rmse:0.05540	validation_1-mae:0.03921
# [51]	validation_0-rmse:0.03715	validation_0-mae:0.02713	validation_1-rmse:0.05535	validation_1-mae:0.03918
# [52]	validation_0-rmse:0.03695	validation_0-mae:0.02699	validation_1-rmse:0.05531	validation_1-mae:0.03915
# [53]	validation_0-rmse:0.03672	validation_0-mae:0.02684	validation_1-rmse:0.05526	validation_1-mae:0.03912
# [54]	validation_0-rmse:0.03648	validation_0-mae:0.02667	validation_1-rmse:0.05519	validation_1-mae:0.03908
# [55]	validation_0-rmse:0.03621	validation_0-mae:0.02649	validation_1-rmse:0.05514	validation_1-mae:0.03906
# [56]	validation_0-rmse:0.03598	validation_0-mae:0.02634	validation_1-rmse:0.05511	validation_1-mae:0.03904
# [57]	validation_0-rmse:0.03584	validation_0-mae:0.02625	validation_1-rmse:0.05509	validation_1-mae:0.03902
# [58]	validation_0-rmse:0.03573	validation_0-mae:0.02617	validation_1-rmse:0.05506	validation_1-mae:0.03900
# [59]	validation_0-rmse:0.03557	validation_0-mae:0.02605	validation_1-rmse:0.05503	validation_1-mae:0.03898
# [60]	validation_0-rmse:0.03536	validation_0-mae:0.02591	validation_1-rmse:0.05499	validation_1-mae:0.03895
# [61]	validation_0-rmse:0.03522	validation_0-mae:0.02581	validation_1-rmse:0.05495	validation_1-mae:0.03894
# [62]	validation_0-rmse:0.03501	validation_0-mae:0.02567	validation_1-rmse:0.05492	validation_1-mae:0.03892
# [63]	validation_0-rmse:0.03486	validation_0-mae:0.02556	validation_1-rmse:0.05489	validation_1-mae:0.03889
# [64]	validation_0-rmse:0.03462	validation_0-mae:0.02540	validation_1-rmse:0.05486	validation_1-mae:0.03887
# [65]	validation_0-rmse:0.03443	validation_0-mae:0.02527	validation_1-rmse:0.05483	validation_1-mae:0.03885
# [66]	validation_0-rmse:0.03426	validation_0-mae:0.02515	validation_1-rmse:0.05481	validation_1-mae:0.03884
# [67]	validation_0-rmse:0.03412	validation_0-mae:0.02506	validation_1-rmse:0.05477	validation_1-mae:0.03881
# [68]	validation_0-rmse:0.03393	validation_0-mae:0.02492	validation_1-rmse:0.05472	validation_1-mae:0.03878
# [69]	validation_0-rmse:0.03380	validation_0-mae:0.02483	validation_1-rmse:0.05471	validation_1-mae:0.03877
# [70]	validation_0-rmse:0.03363	validation_0-mae:0.02472	validation_1-rmse:0.05468	validation_1-mae:0.03875
# [71]	validation_0-rmse:0.03345	validation_0-mae:0.02458	validation_1-rmse:0.05464	validation_1-mae:0.03872
# [72]	validation_0-rmse:0.03333	validation_0-mae:0.02449	validation_1-rmse:0.05462	validation_1-mae:0.03871
# [73]	validation_0-rmse:0.03311	validation_0-mae:0.02434	validation_1-rmse:0.05459	validation_1-mae:0.03869
# [74]	validation_0-rmse:0.03300	validation_0-mae:0.02426	validation_1-rmse:0.05456	validation_1-mae:0.03867
# [75]	validation_0-rmse:0.03282	validation_0-mae:0.02413	validation_1-rmse:0.05453	validation_1-mae:0.03865
# [76]	validation_0-rmse:0.03268	validation_0-mae:0.02403	validation_1-rmse:0.05451	validation_1-mae:0.03863
# [77]	validation_0-rmse:0.03252	validation_0-mae:0.02392	validation_1-rmse:0.05451	validation_1-mae:0.03863
# [78]	validation_0-rmse:0.03238	validation_0-mae:0.02381	validation_1-rmse:0.05449	validation_1-mae:0.03862
# [79]	validation_0-rmse:0.03229	validation_0-mae:0.02374	validation_1-rmse:0.05446	validation_1-mae:0.03860
# [80]	validation_0-rmse:0.03218	validation_0-mae:0.02366	validation_1-rmse:0.05444	validation_1-mae:0.03859
# [81]	validation_0-rmse:0.03209	validation_0-mae:0.02359	validation_1-rmse:0.05443	validation_1-mae:0.03858
# [82]	validation_0-rmse:0.03184	validation_0-mae:0.02342	validation_1-rmse:0.05442	validation_1-mae:0.03858
# [83]	validation_0-rmse:0.03175	validation_0-mae:0.02335	validation_1-rmse:0.05440	validation_1-mae:0.03857
# [84]	validation_0-rmse:0.03166	validation_0-mae:0.02328	validation_1-rmse:0.05439	validation_1-mae:0.03856
# [85]	validation_0-rmse:0.03150	validation_0-mae:0.02317	validation_1-rmse:0.05437	validation_1-mae:0.03855
# [86]	validation_0-rmse:0.03136	validation_0-mae:0.02307	validation_1-rmse:0.05434	validation_1-mae:0.03852
# [87]	validation_0-rmse:0.03125	validation_0-mae:0.02299	validation_1-rmse:0.05433	validation_1-mae:0.03852
# [88]	validation_0-rmse:0.03107	validation_0-mae:0.02286	validation_1-rmse:0.05431	validation_1-mae:0.03851
# [89]	validation_0-rmse:0.03097	validation_0-mae:0.02279	validation_1-rmse:0.05430	validation_1-mae:0.03850
# [90]	validation_0-rmse:0.03084	validation_0-mae:0.02270	validation_1-rmse:0.05429	validation_1-mae:0.03849
# [91]	validation_0-rmse:0.03073	validation_0-mae:0.02262	validation_1-rmse:0.05427	validation_1-mae:0.03848
# [92]	validation_0-rmse:0.03060	validation_0-mae:0.02253	validation_1-rmse:0.05425	validation_1-mae:0.03847
# [93]	validation_0-rmse:0.03043	validation_0-mae:0.02240	validation_1-rmse:0.05424	validation_1-mae:0.03846
# [94]	validation_0-rmse:0.03034	validation_0-mae:0.02234	validation_1-rmse:0.05421	validation_1-mae:0.03845
# [95]	validation_0-rmse:0.03017	validation_0-mae:0.02222	validation_1-rmse:0.05419	validation_1-mae:0.03843
# [96]	validation_0-rmse:0.03009	validation_0-mae:0.02216	validation_1-rmse:0.05419	validation_1-mae:0.03843
# [97]	validation_0-rmse:0.02997	validation_0-mae:0.02207	validation_1-rmse:0.05417	validation_1-mae:0.03842
# [98]	validation_0-rmse:0.02985	validation_0-mae:0.02198	validation_1-rmse:0.05416	validation_1-mae:0.03841
# [99]	validation_0-rmse:0.02975	validation_0-mae:0.02191	validation_1-rmse:0.05414	validation_1-mae:0.03840
# Features used for model training =  ['aspect', 'slope', 'EVI', 'MNDWI', 'MSAVI', 'NDMI', 'NDVI', 'SAVI', 'SR_B5', 'SR_B6', 'SR_B7', 'ST_B10']
# Number of principal components used for model training =  None
# MAE =  0.038397392384321855
# MSE =  0.002930818486456148
# R2 Score =  0.8347297317404343
# Adjusted R2 Score =  0.8346067246561997

# %%
trained_model = train_results_mariposa21['estimator']

# %%
X = test_df.drop('smi', axis = 1)
y = test_df['smi']

# %%
y_pred_mariposa22 = trained_model.predict(X)

# %%
r2_Mariposa22 = r2_score(y, y_pred_mariposa22)
r2_Mariposa22
# Out:
# 0.7458687065063063
